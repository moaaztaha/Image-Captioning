# %%
# get the code for kaggle
# !git clone https://github.com/moaaztaha/Image-Captioning
py_files_path = '/kaggle/working/Image-Captioning/'
import sys
sys.path.append(py_files_path)
# Out:
# Cloning into 'Image-Captioning'...
# remote: Enumerating objects: 261, done.
# remote: Counting objects: 100% (261/261), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 261 (delta 155), reused 166 (delta 62), pack-reused 0
# Receiving objects: 100% (261/261), 14.72 MiB | 6.06 MiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import time 
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence
from models import Encoder, DecoderWithAttention
from dataset import *
from utils import *
from train import *
from nltk.translate.bleu_score import corpus_bleu

# %%
# Model parameters
encoder_dim = 2048 # resnet101
emb_dim = 512  # dimension of word embeddings
attention_dim = 512  # dimension of attention linear layers
decoder_dim = 512  # dimension of decoder RNN
dropout = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # sets device for model and PyTorch tensors
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# training parameters
epochs = 35  # number of epochs to train for (if early stopping is not triggered)
batch_size = 128
workers = 4
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning
decoder_lr = 4e-4  # learning rate for decoder
fine_tune_encoder = False  # fine-tune encoder?
checkpoint = None  # path to checkpoint, None if none

# %%
DATA_NAME = 'flickr8k_5_cap_per_img_2_min_word_freq_resnet101'

# local
# DATA_JSON_PATH = 'data.json'
# IMGS_PATH = 'flickr/Images/'
# kaggle paths
DATA_JSON_PATH = '/kaggle/working/Image-Captioning/data.json'
IMGS_PATH = '../input/flickr8kimagescaptions/flickr8k/images/'

# %%
# load vocab
vocab = build_vocab(DATA_JSON_PATH)
# Out:
# 100%|██████████| 30000/30000 [00:00<00:00, 222853.92it/s]

# %%
len(vocab)
# Out:
# 4451

# %%
t_params = {
    'data_name': DATA_NAME,
    'imgs_path': IMGS_PATH,
    'df_path': DATA_JSON_PATH,
    'vocab': vocab,
    'epochs': epochs,
    'batch_size': batch_size,
    'workers': workers,
    'decoder_lr': decoder_lr,
    'encoder_lr': encoder_lr,
    'fine_tune_encoder': fine_tune_encoder
}

m_params = {
    'attention_dim': attention_dim,
    'embed_dim': emb_dim,
    'decoder_dim': decoder_dim,
    'encoder_dim': encoder_dim,
    'dropout': dropout
}

epochs=100
fit(t_params=t_params, m_params=m_params)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
#   0%|          | 0.00/170M [00:00<?, ?B/s]
# Loading Data
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000
# __________________________________________________
# -------------------- Fitting --------------------
# Epoch: [0][0/235]	Batch Time 6.536 (6.536)	Data Load Time 3.732 (3.732)	Loss 9.3081 (9.3081)	Top-5 Accuracy 0.394 (0.394)
# Epoch: [0][100/235]	Batch Time 1.540 (0.989)	Data Load Time 0.824 (0.244)	Loss 5.5076 (6.1721)	Top-5 Accuracy 43.079 (36.016)
# Epoch: [0][200/235]	Batch Time 1.230 (0.959)	Data Load Time 0.546 (0.223)	Loss 4.7506 (5.6842)	Top-5 Accuracy 54.714 (42.512)
# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 5

# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 5.801 (5.801)	Loss 5.5795 (5.5795)	Top-5 Accuracy 58.758 (58.758)
#
#  * LOSS - 5.311, TOP-5 ACCURACY - 58.804, BLEU-4 - 0.007139626968713665
#
#
# Epochs since last improvement: (1,)
# Epoch: [10][0/235]	Batch Time 4.511 (4.511)	Data Load Time 3.796 (3.796)	Loss 3.3944 (3.3944)	Top-5 Accuracy 72.915 (72.915)
# Epoch: [10][100/235]	Batch Time 1.583 (0.965)	Data Load Time 0.896 (0.237)	Loss 3.3151 (3.3039)	Top-5 Accuracy 73.590 (74.259)
# Epoch: [10][200/235]	Batch Time 0.732 (0.949)	Data Load Time 0.001 (0.218)	Loss 3.3865 (3.3239)	Top-5 Accuracy 73.004 (73.917)
# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 4.804 (4.804)	Loss 5.7508 (5.7508)	Top-5 Accuracy 56.596 (56.596)
#
#  * LOSS - 5.404, TOP-5 ACCURACY - 58.953, BLEU-4 - 0.006863062816824187
#
#
# Epochs since last improvement: (2,)
# Epoch: [11][0/235]	Batch Time 4.418 (4.418)	Data Load Time 3.717 (3.717)	Loss 3.2742 (3.2742)	Top-5 Accuracy 74.311 (74.311)
# Epoch: [11][100/235]	Batch Time 1.356 (0.983)	Data Load Time 0.642 (0.249)	Loss 3.1926 (3.2364)	Top-5 Accuracy 75.628 (75.087)
# Epoch: [11][200/235]	Batch Time 1.534 (0.958)	Data Load Time 0.847 (0.218)	Loss 3.3113 (3.2461)	Top-5 Accuracy 73.186 (74.971)
# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 4.832 (4.832)	Loss 5.1170 (5.1170)	Top-5 Accuracy 62.156 (62.156)
#
#  * LOSS - 5.396, TOP-5 ACCURACY - 59.283, BLEU-4 - 0.007157166990122306
#
#
# Epochs since last improvement: (3,)
# Epoch: [12][0/235]	Batch Time 5.047 (5.047)	Data Load Time 4.303 (4.303)	Loss 3.1580 (3.1580)	Top-5 Accuracy 76.751 (76.751)
# Epoch: [12][100/235]	Batch Time 1.798 (0.971)	Data Load Time 0.898 (0.240)	Loss 3.1427 (3.1553)	Top-5 Accuracy 75.994 (76.353)
# Epoch: [12][200/235]	Batch Time 1.337 (0.953)	Data Load Time 0.638 (0.220)	Loss 3.1731 (3.1731)	Top-5 Accuracy 76.461 (76.072)
# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 4.744 (4.744)	Loss 5.2729 (5.2729)	Top-5 Accuracy 60.070 (60.070)
#
#  * LOSS - 5.419, TOP-5 ACCURACY - 59.050, BLEU-4 - 0.0070071311811314525
#
#
# Epochs since last improvement: (4,)
# Epoch: [13][0/235]	Batch Time 4.177 (4.177)	Data Load Time 3.300 (3.300)	Loss 3.0760 (3.0760)	Top-5 Accuracy 77.074 (77.074)
# Epoch: [13][100/235]	Batch Time 1.590 (0.968)	Data Load Time 0.928 (0.229)	Loss 3.2089 (3.0815)	Top-5 Accuracy 75.329 (77.567)
# Epoch: [13][200/235]	Batch Time 1.369 (0.955)	Data Load Time 0.691 (0.223)	Loss 3.1046 (3.1003)	Top-5 Accuracy 76.619 (77.210)
# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 4.957 (4.957)	Loss 5.3437 (5.3437)	Top-5 Accuracy 58.656 (58.656)
#
#  * LOSS - 5.403, TOP-5 ACCURACY - 59.039, BLEU-4 - 0.006687832113565425
#
#
# Epochs since last improvement: (5,)
# Epoch: [14][0/235]	Batch Time 4.604 (4.604)	Data Load Time 3.882 (3.882)	Loss 3.1119 (3.1119)	Top-5 Accuracy 76.762 (76.762)
# Epoch: [14][100/235]	Batch Time 1.350 (0.977)	Data Load Time 0.658 (0.250)	Loss 2.9872 (3.0089)	Top-5 Accuracy 78.917 (78.566)
# Epoch: [14][200/235]	Batch Time 1.596 (0.961)	Data Load Time 0.822 (0.228)	Loss 3.1234 (3.0308)	Top-5 Accuracy 76.061 (78.250)
# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 5.040 (5.040)	Loss 5.6247 (5.6247)	Top-5 Accuracy 56.390 (56.390)
#
#  * LOSS - 5.462, TOP-5 ACCURACY - 59.257, BLEU-4 - 0.006975277991946527
#
#
# Epochs since last improvement: (6,)
# Epoch: [15][0/235]	Batch Time 4.175 (4.175)	Data Load Time 3.469 (3.469)	Loss 2.8830 (2.8830)	Top-5 Accuracy 80.344 (80.344)
# Epoch: [15][100/235]	Batch Time 1.519 (0.968)	Data Load Time 0.805 (0.238)	Loss 3.0410 (2.9430)	Top-5 Accuracy 77.174 (79.665)
# Epoch: [15][200/235]	Batch Time 1.602 (0.948)	Data Load Time 0.872 (0.212)	Loss 2.9512 (2.9607)	Top-5 Accuracy 79.429 (79.429)
# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 5.225 (5.225)	Loss 5.6475 (5.6475)	Top-5 Accuracy 59.095 (59.095)
#
#  * LOSS - 5.461, TOP-5 ACCURACY - 59.195, BLEU-4 - 0.0069047404108553145
#
#
# Epochs since last improvement: (7,)
# Epoch: [16][0/235]	Batch Time 4.699 (4.699)	Data Load Time 3.999 (3.999)	Loss 2.8520 (2.8520)	Top-5 Accuracy 81.934 (81.934)
# Epoch: [16][100/235]	Batch Time 1.418 (0.970)	Data Load Time 0.680 (0.242)	Loss 2.8909 (2.8922)	Top-5 Accuracy 80.781 (80.403)
# Epoch: [16][200/235]	Batch Time 1.441 (0.949)	Data Load Time 0.785 (0.216)	Loss 2.9090 (2.9075)	Top-5 Accuracy 80.408 (80.198)
# __________________________________________________
# -------------------- Validation --------------------
# Validation: [0/40]	Batch Time 5.195 (5.195)	Loss 5.4455 (5.4455)	Top-5 Accuracy 60.589 (60.589)
#
#  * LOSS - 5.543, TOP-5 ACCURACY - 59.054, BLEU-4 - 0.006939381742713682
#
#
# Epochs since last improvement: (8,)
# Decaying learning rate
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-7a8cb27ea12c> in <module>
#      21
#      22 epochs=100
# ---> 23 fit(t_params=t_params, m_params=m_params)
#
# /kaggle/working/Image-Captioning/train.py in fit(t_params, checkpoint, m_params)
#     279             break
#     280         if epochs_since_improvement > 0 and epochs_since_improvement % 8 == 0:
# --> 281             adjust_learning_rate(decoder_optimizer, 0.8)
#     282             if fine_tune_encoder:
#     283                 adjust_learning_rate(encoder_optimizer, 0.8)
#
# /kaggle/working/Image-Captioning/utils.py in adjust_learning_rate(optimizer, shrink_factor)
#     191     print('Decaying learning rate')
#     192
# --> 193     for param_group in optimizer.param_groups():
#     194         param_group['lr'] = param_group['lr'] * shrink_factor
#     195
#
# TypeError: 'list' object is not callable

# %% [markdown]
# !ls

# %% [markdown]
# <a href='BEST_checkpoint_flickr8k_5_cap_per_img_2_min_word_freq_resnet101.pth.tar'>download</a>
