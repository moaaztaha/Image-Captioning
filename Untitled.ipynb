# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms


import pandas as pd
import numpy as np
import spacy

from datasets import build_vocab, get_loaders
from models import Img2Seq, EncoderCNN, DecoderLSTM
from utils import print_examples, predict_test, print_scores, get_test_data
from utils import show_image

from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
import time, math, random
# %matplotlib inline

# %%
# making our results reproducable
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
MODEL_PATH = 'models/LSTM_FT.pth'
IMAGES_PATH = 'flickr/Images/'
DF_PATH = 'data.csv'
TEST_DF_PATH = 'test.csv'
TEST_EXAMPLES_PATH = 'test_examples/'

# %%
vocab = build_vocab(DF_PATH)
pad_idx = vocab.stoi['<pad>']

# %%
HID_DIM = 256
EMB_DIM = 256
DROPOUT = .5
VOCAB_LENGTH = len(vocab)
TRAIN_CNN = False
bs = 256
lr = 3e-3

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

encoder = EncoderCNN(HID_DIM, DROPOUT)
decoder = DecoderLSTM(EMB_DIM, HID_DIM, VOCAB_LENGTH, DROPOUT)

model = Img2Seq(encoder, decoder, device).to(device)

# %%
# transforms 
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
# load model
model = Img2Seq(encoder, decoder, device).to(device)
model.load_state_dict(torch.load(MODEL_PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Testing model outputs

# %%
train_loader, valid_loader = get_loaders(1, IMAGES_PATH, DF_PATH, transform, vocab)
# Out:
# Dataset split: train
# Unique Image: 6000
# Size: 30000
# Dataset split: val
# Unique Image: 1000
# Size: 5000

# %%
xb, yb = next(iter(train_loader))

# %%
xb.shape, yb.shape
# Out:
# (torch.Size([1, 3, 224, 224]), torch.Size([7, 1]))

# %%
xb.squeeze().shape
# Out:
# torch.Size([3, 224, 224])

# %%
show_image(xb.squeeze())
' '.join(vocab.itos[i.item()] for i in yb)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <built-in method size of Tensor object at 0x7f63f307b5f0>
# '<sos> a basketball player dribbles . <eos>'

# %%
# load model
model = Img2Seq(encoder, decoder, device).to(device)
model.load_state_dict(torch.load(MODEL_PATH))
# Out:
# <All keys matched successfully>

# %%
output = model(xb.to(device), yb.to(device))

# %%
output
# Out:
# tensor([[[ -1.4449,  14.4169,   0.2475,  ...,  -2.4265,  -3.2413,  -4.3386]],
#
#         [[ -5.6209,   1.7275,  -0.5667,  ...,  -3.7826,  -9.4247,  -6.5112]],
#
#         [[ -4.8900,   0.2479,  -3.8763,  ...,  -7.0114,  -3.8353,  -5.5303]],
#
#         ...,
#
#         [[ -8.1668,   2.2451,   4.5339,  ..., -12.9738, -13.4715, -11.9501]],
#
#         [[ -7.8949,   3.9641,  14.5585,  ..., -12.2926,  -8.3514,  -7.8919]],
#
#         [[ -8.7027,   0.9767,  10.3694,  ..., -13.2114, -10.5175, -10.4054]]],
#        device='cuda:0', grad_fn=<AddBackward0>)

# %%
output.argmax()
# Out:
# tensor(26768, device='cuda:0')

# %%
output.shape
# Out:
# torch.Size([8, 1, 4461])

# %%
len(vocab)
# Out:
# 4461

# %%
yb.shape
# Out:
# torch.Size([7, 1])
