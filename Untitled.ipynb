# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
py_files_path = '../'
import sys
sys.path.append(py_files_path)

# %%
from datasets import build_vocab

# %%
vocab = build_vocab('../data.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('../data.csv')
df.head()
# Out:
#                    file_name  split  \
# 0  2513260012_03d33305cf.jpg  train
# 1  2513260012_03d33305cf.jpg  train
# 2  2513260012_03d33305cf.jpg  train
# 3  2513260012_03d33305cf.jpg  train
# 4  2513260012_03d33305cf.jpg  train
#
#                                              caption  tok_len  \
# 0  A black dog is running after a white dog in th...       12
# 1           Black dog chasing brown dog through snow        7
# 2  Two dogs chase each other across the snowy gro...        9
# 3               Two dogs play together in the snow .        7
# 4  Two dogs running through a low lying body of w...       10
#
#                                               tokens
# 0  ['a', 'black', 'dog', 'is', 'running', 'after'...
# 1  ['black', 'dog', 'chasing', 'brown', 'dog', 't...
# 2  ['two', 'dogs', 'chase', 'each', 'other', 'acr...
# 3  ['two', 'dogs', 'play', 'together', 'in', 'the...
# 4  ['two', 'dogs', 'running', 'through', 'a', 'lo...

# %%
s = "this is a test sentence"
s
# Out:
# 'this is a test sentence'

# %%
n = vocab.numericalize(s)
n
# Out:
# [1, 463, 18, 4, 2339, 3, 2]

# %%
' '.join(vocab.itos[i] for i in n)
# Out:
# '<sos> this is a test <unk> <eos>'

# %%
from dataset import CaptionDataset

# %%
ds = CaptionDataset('../flickr/Images/', '../data.csv', vocab)
# Out:
# Dataset split: train
# Unique images: 6000
# Total size: 30000

# %%
img, cap, cap_len = ds[0]

# %%
import matplotlib.pyplot as plt
plt.imshow(img.permute(1, 2, 0))

# %%
' '.join(vocab.itos[i.item()] for i in cap)
# Out:
# '<sos> a black dog is running after a white dog in the snow . <eos>'

# %%
cap_len
# Out:
# 12

# %%
ds = CaptionDataset('../flickr/Images/', '../data.csv', vocab, split='val')
# Out:
# Dataset split: val
# Unique images: 1000
# Total size: 5000

# %%
img, caption, cap_len, all_captions = ds[0]

# %%
caption
# Out:
# tensor([   1,    8,   64,  986,  321,   51,   35,    4,  359,   18,  481, 2502,
#          108,    8,  348,   36,  187,   64,    9,    2])

# %%
len(all_captions)
# Out:
# 5

# %%
all_captions[0]
# Out:
# [1,
#  8,
#  64,
#  986,
#  321,
#  51,
#  35,
#  4,
#  359,
#  18,
#  481,
#  2502,
#  108,
#  8,
#  348,
#  36,
#  187,
#  64,
#  9,
#  2]

# %% [markdown]
# ### Testing Encoder

# %%
from models import Encoder

# %%
model = Encoder(256)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/kelwa/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
ds = CaptionDataset('../flickr/Images/', '../data.csv', vocab)
img, cap, cap_len = ds[0]
img.shape, cap.shape
# Out:
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# (torch.Size([3, 399, 500]), torch.Size([15]))

# %%
model(img.unsqueeze(0)).shape
# Out:
# torch.Size([1, 256, 256, 512])

# %%
import torchvision.models as models
resnet = models.resnet34(pretrained=True)

# %%
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
from nltk.translate.bleu_score import corpus_bleu

# %%
from torchtext.data.metrics import bleu_score

# %%
bleu_score(list_of_hypotheses, list_of_references, max_n=3, weights=[.33, .33, .33])
# Out:
# 0.0

# %%
hypothesis = ['This', 'is', 'cat', 'This', 'is', 'cat'] 
reference = ['This', 'is', 'a', 'cat', 'This', 'is', 'cat']
references = [reference] # list of references for 1 sentence.
list_of_references = [references] # list of references for all sentences in corpus.
list_of_hypotheses = [hypothesis]

# %%
corpus_bleu(list_of_references, list_of_hypotheses)
# Out:
# 0.5115078115793242

# %%
from utils import print_scores

print_scores(list_of_hypotheses, list_of_references)
# Out:
# 1: 84.64817248906141
# 2: 75.71162623611156
# 3: 62.56009219956626
# 4: 51.150778475239655

# %%
from train import validate

# %%
from dataset import get_loaders, build_vocab

# %%
from torchvision import transforms

# %%
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

# %%
vocab = build_vocab('data.json')
# Out:
# 100%|██████████| 30000/30000 [00:00<00:00, 391726.22it/s]

# %%
_, val_load = get_loaders(8, 'flickr/Images/', 'data.json', transforms, vocab)
# Out:
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000

# %%
validate(val_load, )
