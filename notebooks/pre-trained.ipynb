# %%
# !rm -r Image-Captioning/

# %%
# # get the code for kaggle
# !git clone https://github.com/moaaztaha/Image-Captioning
py_files_path = 'Image-Captioning/'
import sys
sys.path.append(py_files_path)
# Out:
# Cloning into 'Image-Captioning'...
# remote: Enumerating objects: 506, done.
# remote: Counting objects: 100% (506/506), done.
# remote: Compressing objects: 100% (217/217), done.
# remote: Total 506 (delta 312), reused 475 (delta 281), pack-reused 0
# Receiving objects: 100% (506/506), 36.49 MiB | 13.91 MiB/s, done.
# Resolving deltas: 100% (312/312), done.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import time 
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence
from models import Encoder, DecoderWithAttention
from dataset import *
from utils import *
from train import *
from torch.utils.tensorboard import SummaryWriter
from os import path as osp

# %%
# Model parameters
encoder_dim = 2048 # resnet101
emb_dim = 300  # dimension of word embeddings
attention_dim = 512  # dimension of attention linear layers
decoder_dim = 512  # dimension of decoder RNN
dropout = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # sets device for model and PyTorch tensors
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# training parameters
epochs = 30  # number of epochs to train for (if early stopping is not triggered)
batch_size = 256
workers = 2
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning
decoder_lr = 4e-4  # learning rate for decoder
fine_tune_encoder = False  # fine-tune encoder
pretrained_embeddings = True
fine_tune_embeddings = True
checkpoint = None  # path to checkpoint, None if none

# %%
DATA_NAME = 'flickr8k_tb'

# local
# DATA_JSON_PATH = 'data.json'
# IMGS_PATH = 'flickr/Images/'
# kaggle paths
DATA_JSON_PATH = '/kaggle/working/Image-Captioning/data.json'
IMGS_PATH = '../input/flickr8kimagescaptions/flickr8k/images/'
#colab
# DATA_JSON_PATH = 'Image-Captioning/data.json'
# IMGS_PATH = 'flickr8k/images/'

# %%
# load vocab
vocab = build_vocab(DATA_JSON_PATH)
vocab_len = len(vocab); vocab_len
# Out:
# 100%|██████████| 40000/40000 [00:00<00:00, 216834.42it/s]
# 5089

# %% [markdown]
# ### Pre-trained Embeddings

# %%
glove = pd.read_csv('../input/glove6b/glove.6B.300d.txt', sep=' ', quoting=3, header=None, index_col=0)
glove_embedding = {key: val.values for key, val in glove.T.items()}

# %%
def create_embedding_matrix(vocab, embedding_dict, dimension):
    embedding_matrix = np.zeros((len(vocab), dimension))
    
    for word, index in vocab.stoi.items():
        if word in embedding_dict:
            embedding_matrix[index] = embedding_dict[word]
        else: 
            embedding_matrix[index] = np.random.uniform(-.1, .1, size=dimension)
    return embedding_matrix

# %%
embedding_matrix = create_embedding_matrix(vocab, glove_embedding, 300)

# %%
embedding_matrix.shape
# Out:
# (5089, 300)

# %%
t_params = {
    'data_name': DATA_NAME,
    'imgs_path': IMGS_PATH,
    'df_path': DATA_JSON_PATH,
    'vocab': vocab,
    'epochs': epochs,
    'batch_size': batch_size,
    'workers': workers,
    'decoder_lr': decoder_lr,
    'encoder_lr': encoder_lr,
    'fine_tune_encoder': fine_tune_encoder,
    'pretrained_embeddings': pretrained_embeddings,
    'fine_tune_embeddings': fine_tune_embeddings,
}

m_params = {
    'attention_dim': attention_dim,
    'embed_dim': emb_dim,
    'decoder_dim': decoder_dim,
    'encoder_dim': encoder_dim,
    'dropout': dropout,
    'embeddings_matrix': embedding_matrix
}

logger_dic = {
    'decoder_lr': decoder_lr,
    'encoder_lr': encoder_lr,
    'fine_tune_encoder': fine_tune_encoder,
    'pretrained_embeddings': pretrained_embeddings,
    'max_seq_length': 100,
    'vocab_size': vocab_len,
    'enocder': 'resnet101',
    'dropout': dropout,
    'attention_dim': attention_dim,
    'embed_dim': emb_dim,
    'decoder_dim': decoder_dim,
    'encoder_dim': encoder_dim 
    
}


t_params
# Out:
# {'data_name': 'flickr8k_tb',
#  'imgs_path': '../input/flickr8kimagescaptions/flickr8k/images/',
#  'df_path': '/kaggle/working/Image-Captioning/data.json',
#  'vocab': <dataset.Vocabulary at 0x7f0388ab1990>,
#  'epochs': 20,
#  'batch_size': 256,
#  'workers': 2,
#  'decoder_lr': 0.0004,
#  'encoder_lr': 0.0001,
#  'fine_tune_encoder': False,
#  'pretrained_embeddings': True,
#  'fine_tune_embeddings': True}

# %%
# experiment name
name = DATA_NAME + "_pretrained_glove"
# path
log_dir = 'experiments'

logger = SummaryWriter(log_dir=osp.join(log_dir, name))

# %%
fit(t_params=t_params, m_params=m_params, logger=logger)
# Out:
# Loading Data
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000
# __________________________________________________
# -------------------- Fitting --------------------
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [0][0/118]	Batch Time 6.601 (6.601)	Data Load Time 5.134 (5.134)	Loss 9.4666 (9.4666)	Top-5 Accuracy 0.000 (0.000)
# Epoch: [0][100/118]	Batch Time 2.796 (2.295)	Data Load Time 1.431 (0.964)	Loss 4.7633 (5.4140)	Top-5 Accuracy 54.613 (46.523)
# Epoch train time 266.007 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 7.088 (7.088)	Loss 5.5493 (5.5493)	Top-5 Accuracy 50.976 (50.976)
# ----- Bleu-n Scores -----
# 1: 58.915703682508834
# 2: 32.81225167382208
# 3: 15.582803588027405
# 4: 7.495922958508829
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 5.322, TOP-5 ACCURACY - 52.010, BLEU-4 - 7.495922958508829
#
# Epoch validation time 57.103 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [1][0/118]	Batch Time 4.882 (4.882)	Data Load Time 3.462 (3.462)	Loss 4.7628 (4.7628)	Top-5 Accuracy 54.939 (54.939)
# Epoch: [1][100/118]	Batch Time 3.415 (2.178)	Data Load Time 2.001 (0.840)	Loss 4.4329 (4.5519)	Top-5 Accuracy 59.321 (57.836)
# Epoch train time 253.719 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 6.318 (6.318)	Loss 5.0247 (5.0247)	Top-5 Accuracy 56.527 (56.527)
# ----- Bleu-n Scores -----
# 1: 62.757365216025185
# 2: 37.04163305840623
# 3: 20.488262084353913
# 4: 11.601522403707232
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 5.144, TOP-5 ACCURACY - 55.377, BLEU-4 - 11.601522403707232
#
# Epoch validation time 54.626 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [2][0/118]	Batch Time 5.034 (5.034)	Data Load Time 3.559 (3.559)	Loss 4.4515 (4.4515)	Top-5 Accuracy 58.025 (58.025)
# Epoch: [2][100/118]	Batch Time 2.902 (2.203)	Data Load Time 1.562 (0.861)	Loss 4.2764 (4.2878)	Top-5 Accuracy 61.063 (61.136)
# Epoch train time 255.800 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.692 (5.692)	Loss 5.1395 (5.1395)	Top-5 Accuracy 56.597 (56.597)
# ----- Bleu-n Scores -----
# 1: 62.180797594574464
# 2: 37.996776861454244
# 3: 21.37798341833544
# 4: 12.219126043956493
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 5.074, TOP-5 ACCURACY - 57.078, BLEU-4 - 12.219126043956493
#
# Epoch validation time 54.026 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [3][0/118]	Batch Time 5.396 (5.396)	Data Load Time 4.030 (4.030)	Loss 4.2585 (4.2585)	Top-5 Accuracy 60.821 (60.821)
# Epoch: [3][100/118]	Batch Time 2.596 (2.181)	Data Load Time 1.350 (0.840)	Loss 4.0654 (4.1196)	Top-5 Accuracy 64.094 (63.274)
# Epoch train time 253.709 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.557 (5.557)	Loss 4.9450 (4.9450)	Top-5 Accuracy 59.126 (59.126)
# ----- Bleu-n Scores -----
# 1: 64.2835966617212
# 2: 39.21871134963128
# 3: 22.19801119834214
# 4: 12.769868818395222
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 5.039, TOP-5 ACCURACY - 57.980, BLEU-4 - 12.769868818395222
#
# Epoch validation time 52.845 (epoch_time.avg:.3f)
# Epoch     4: reducing learning rate of group 0 to 4.0000e-05.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [4][0/118]	Batch Time 5.192 (5.192)	Data Load Time 3.775 (3.775)	Loss 4.2035 (4.2035)	Top-5 Accuracy 61.338 (61.338)
# Epoch: [4][100/118]	Batch Time 2.872 (2.140)	Data Load Time 1.492 (0.799)	Loss 3.9185 (3.9791)	Top-5 Accuracy 65.812 (64.988)
# Epoch train time 249.404 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 6.097 (6.097)	Loss 4.8867 (4.8867)	Top-5 Accuracy 58.859 (58.859)
# ----- Bleu-n Scores -----
# 1: 65.96981124641422
# 2: 41.92910775960854
# 3: 25.05523787157306
# 4: 15.009206927495697
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.978, TOP-5 ACCURACY - 59.419, BLEU-4 - 15.009206927495697
#
# Epoch validation time 53.246 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [5][0/118]	Batch Time 5.026 (5.026)	Data Load Time 3.611 (3.611)	Loss 3.8856 (3.8856)	Top-5 Accuracy 65.597 (65.597)
# Epoch: [5][100/118]	Batch Time 3.226 (2.180)	Data Load Time 1.891 (0.839)	Loss 3.8987 (3.9471)	Top-5 Accuracy 65.514 (65.446)
# Epoch train time 255.335 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 6.030 (6.030)	Loss 4.9587 (4.9587)	Top-5 Accuracy 59.629 (59.629)
# ----- Bleu-n Scores -----
# 1: 66.16501437822183
# 2: 41.96888719174818
# 3: 25.155320042434088
# 4: 15.210010058737733
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.967, TOP-5 ACCURACY - 59.515, BLEU-4 - 15.210010058737733
#
# Epoch validation time 54.992 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [6][0/118]	Batch Time 5.700 (5.700)	Data Load Time 4.049 (4.049)	Loss 3.9815 (3.9815)	Top-5 Accuracy 64.681 (64.681)
# Epoch: [6][100/118]	Batch Time 3.424 (2.229)	Data Load Time 2.058 (0.883)	Loss 4.0082 (3.9225)	Top-5 Accuracy 64.380 (65.864)
# Epoch train time 259.493 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.619 (5.619)	Loss 5.0701 (5.0701)	Top-5 Accuracy 59.502 (59.502)
# ----- Bleu-n Scores -----
# 1: 66.01599339557409
# 2: 42.04746023685605
# 3: 25.101845665254107
# 4: 15.12134427908548
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.965, TOP-5 ACCURACY - 59.708, BLEU-4 - 15.12134427908548
#
# Epoch validation time 54.294 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# Epoch     7: reducing learning rate of group 0 to 4.0000e-06.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [7][0/118]	Batch Time 5.041 (5.041)	Data Load Time 3.515 (3.515)	Loss 3.9172 (3.9172)	Top-5 Accuracy 65.575 (65.575)
# Epoch: [7][100/118]	Batch Time 2.639 (2.152)	Data Load Time 1.368 (0.807)	Loss 3.8963 (3.9153)	Top-5 Accuracy 65.908 (65.921)
# Epoch train time 252.640 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.580 (5.580)	Loss 4.9722 (4.9722)	Top-5 Accuracy 59.556 (59.556)
# ----- Bleu-n Scores -----
# 1: 66.03072598067088
# 2: 42.078295560498354
# 3: 25.22254326752995
# 4: 15.213620968904944
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.977, TOP-5 ACCURACY - 59.687, BLEU-4 - 15.213620968904944
#
# Epoch validation time 52.802 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [8][0/118]	Batch Time 5.002 (5.002)	Data Load Time 3.605 (3.605)	Loss 3.9675 (3.9675)	Top-5 Accuracy 65.863 (65.863)
# Epoch: [8][100/118]	Batch Time 3.097 (2.190)	Data Load Time 1.616 (0.849)	Loss 3.8725 (3.9106)	Top-5 Accuracy 66.368 (65.881)
# Epoch train time 255.298 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.623 (5.623)	Loss 4.7886 (4.7886)	Top-5 Accuracy 60.693 (60.693)
# ----- Bleu-n Scores -----
# 1: 66.06445671280734
# 2: 42.09612163325106
# 3: 25.19692903534616
# 4: 15.157678757351325
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.980, TOP-5 ACCURACY - 59.679, BLEU-4 - 15.157678757351325
#
# Epoch validation time 53.543 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [9][0/118]	Batch Time 4.897 (4.897)	Data Load Time 3.524 (3.524)	Loss 3.8405 (3.8405)	Top-5 Accuracy 66.565 (66.565)
# Epoch: [9][100/118]	Batch Time 3.355 (2.208)	Data Load Time 1.738 (0.866)	Loss 3.9378 (3.9095)	Top-5 Accuracy 65.953 (66.023)
# Epoch train time 255.829 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.931 (5.931)	Loss 5.0221 (5.0221)	Top-5 Accuracy 58.505 (58.505)
# ----- Bleu-n Scores -----
# 1: 66.08212599470424
# 2: 42.08055928891048
# 3: 25.143074929724126
# 4: 15.147370607153618
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.982, TOP-5 ACCURACY - 59.658, BLEU-4 - 15.147370607153618
#
# Epoch validation time 53.100 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (2,)
# Epoch    10: reducing learning rate of group 0 to 4.0000e-07.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [10][0/118]	Batch Time 5.028 (5.028)	Data Load Time 3.507 (3.507)	Loss 3.9447 (3.9447)	Top-5 Accuracy 65.904 (65.904)
# Epoch: [10][100/118]	Batch Time 2.720 (2.169)	Data Load Time 1.394 (0.824)	Loss 4.0433 (3.9008)	Top-5 Accuracy 63.713 (66.098)
# Epoch train time 252.453 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.413 (5.413)	Loss 4.8705 (4.8705)	Top-5 Accuracy 59.823 (59.823)
# ----- Bleu-n Scores -----
# 1: 66.10427080569939
# 2: 42.12555167196672
# 3: 25.242825195947617
# 4: 15.236695699641146
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.982, TOP-5 ACCURACY - 59.704, BLEU-4 - 15.236695699641146
#
# Epoch validation time 52.767 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [11][0/118]	Batch Time 5.223 (5.223)	Data Load Time 3.793 (3.793)	Loss 3.9255 (3.9255)	Top-5 Accuracy 66.351 (66.351)
# Epoch: [11][100/118]	Batch Time 2.775 (2.166)	Data Load Time 1.524 (0.816)	Loss 3.9173 (3.9010)	Top-5 Accuracy 64.987 (66.090)
# Epoch train time 252.330 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.393 (5.393)	Loss 5.1518 (5.1518)	Top-5 Accuracy 59.024 (59.024)
# ----- Bleu-n Scores -----
# 1: 66.0605550491997
# 2: 42.06839633638471
# 3: 25.139861210782005
# 4: 15.115348033549921
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.981, TOP-5 ACCURACY - 59.664, BLEU-4 - 15.115348033549921
#
# Epoch validation time 53.655 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [12][0/118]	Batch Time 5.053 (5.053)	Data Load Time 3.591 (3.591)	Loss 4.0052 (4.0052)	Top-5 Accuracy 63.889 (63.889)
# Epoch: [12][100/118]	Batch Time 2.771 (2.171)	Data Load Time 1.502 (0.829)	Loss 3.9027 (3.9010)	Top-5 Accuracy 65.561 (66.076)
# Epoch train time 252.646 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 6.266 (6.266)	Loss 5.0836 (5.0836)	Top-5 Accuracy 58.247 (58.247)
# ----- Bleu-n Scores -----
# 1: 66.08471186520374
# 2: 42.081231770595664
# 3: 25.137293728571038
# 4: 15.110334919908908
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.983, TOP-5 ACCURACY - 59.698, BLEU-4 - 15.110334919908908
#
# Epoch validation time 53.909 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (2,)
# Epoch    13: reducing learning rate of group 0 to 4.0000e-08.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [13][0/118]	Batch Time 4.896 (4.896)	Data Load Time 3.487 (3.487)	Loss 3.9599 (3.9599)	Top-5 Accuracy 65.619 (65.619)
# Epoch: [13][100/118]	Batch Time 3.250 (2.157)	Data Load Time 1.865 (0.813)	Loss 3.9821 (3.9026)	Top-5 Accuracy 65.364 (66.004)
# Epoch train time 251.261 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.280 (5.280)	Loss 5.0045 (5.0045)	Top-5 Accuracy 60.368 (60.368)
# ----- Bleu-n Scores -----
# 1: 66.10033395772405
# 2: 42.070622762152425
# 3: 25.124854791240043
# 4: 15.095060780284284
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.982, TOP-5 ACCURACY - 59.675, BLEU-4 - 15.095060780284284
#
# Epoch validation time 53.182 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (3,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [14][0/118]	Batch Time 5.071 (5.071)	Data Load Time 3.692 (3.692)	Loss 3.8385 (3.8385)	Top-5 Accuracy 67.414 (67.414)
# Epoch: [14][100/118]	Batch Time 2.769 (2.158)	Data Load Time 1.472 (0.808)	Loss 3.8657 (3.9038)	Top-5 Accuracy 66.324 (66.021)
# Epoch train time 251.624 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.776 (5.776)	Loss 5.0173 (5.0173)	Top-5 Accuracy 59.781 (59.781)
# ----- Bleu-n Scores -----
# 1: 66.08705969250673
# 2: 42.08676339443894
# 3: 25.158031943072075
# 4: 15.11688192686112
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.984, TOP-5 ACCURACY - 59.687, BLEU-4 - 15.11688192686112
#
# Epoch validation time 53.173 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (4,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [15][0/118]	Batch Time 5.562 (5.562)	Data Load Time 4.159 (4.159)	Loss 3.8999 (3.8999)	Top-5 Accuracy 66.360 (66.360)
# Epoch: [15][100/118]	Batch Time 2.764 (2.162)	Data Load Time 1.401 (0.826)	Loss 4.0083 (3.9026)	Top-5 Accuracy 64.233 (66.047)
# Epoch train time 251.211 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.707 (5.707)	Loss 5.4150 (5.4150)	Top-5 Accuracy 56.055 (56.055)
# ----- Bleu-n Scores -----
# 1: 66.12040333650113
# 2: 42.15218963954968
# 3: 25.230431845240453
# 4: 15.210174253132132
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.983, TOP-5 ACCURACY - 59.685, BLEU-4 - 15.210174253132132
#
# Epoch validation time 53.207 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (5,)
# No improvement for 3 consecutive epochs, terminating...

# %%
# !ls
# Out:
# BEST_checkpoint_flickr8k_tb.pth.tar  checkpoint_flickr8k_tb.pth.tar
# Image-Captioning		     experiments
# __notebook_source__.ipynb

# %%
# !zip -r BEST_checkpoint_flickr8k_tb.pth.tar experiments
# Out:
#   adding: experiments/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/events.out.tfevents.1624444330.49c0fa9f8e04.42.0 (deflated 67%)

# %%
# !ls -l
# Out:
# total 559392
# -rw-r--r-- 1 root root 286433971 Jun 23 11:56 BEST_checkpoint_flickr8k_tb.pth.tar
# drwxr-xr-x 8 root root      4096 Jun 23 10:31 Image-Captioning
# ---------- 1 root root       263 Jun 23 10:30 __notebook_source__.ipynb
# -rw-r--r-- 1 root root 286367733 Jun 23 11:50 checkpoint_flickr8k_tb.pth.tar
# drwxr-xr-x 3 root root      4096 Jun 23 10:32 experiments

# %%
m = load_checkpoint('checkpoint_flickr8k_tb.pth.tar')
# Out:
# Loaded Checkpoint!!
# Last Epoch: 14
# Best Bleu-4: 15.11688192686112

# %%
fit(t_params=t_params, checkpoint="checkpoint_flickr8k_tb.pth.tar", m_params=m_params, logger=logger)
# Out:
# Loaded Checkpoint!!
# Starting Epoch: 15
# Loading Data
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000
# __________________________________________________
# -------------------- Fitting --------------------
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [15][0/118]	Batch Time 5.065 (5.065)	Data Load Time 3.622 (3.622)	Loss 3.8590 (3.8590)	Top-5 Accuracy 66.766 (66.766)
# Epoch: [15][100/118]	Batch Time 3.545 (2.136)	Data Load Time 2.067 (0.830)	Loss 3.9267 (3.9038)	Top-5 Accuracy 65.809 (66.085)
# Epoch train time 248.314 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.339 (5.339)	Loss 4.9193 (4.9193)	Top-5 Accuracy 60.426 (60.426)
# ----- Bleu-n Scores -----
# 1: 66.06131066911954
# 2: 42.05707192834203
# 3: 25.132566884557594
# 4: 15.150452886353694
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.982, TOP-5 ACCURACY - 59.679, BLEU-4 - 15.150452886353694
#
# Epoch validation time 54.264 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [16][0/118]	Batch Time 5.289 (5.289)	Data Load Time 3.888 (3.888)	Loss 3.9256 (3.9256)	Top-5 Accuracy 65.829 (65.829)
# Epoch: [16][100/118]	Batch Time 2.803 (2.134)	Data Load Time 1.535 (0.833)	Loss 3.8584 (3.9039)	Top-5 Accuracy 67.046 (66.012)
# Epoch train time 247.856 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.485 (5.485)	Loss 4.8846 (4.8846)	Top-5 Accuracy 59.167 (59.167)
# ----- Bleu-n Scores -----
# 1: 66.08532401616208
# 2: 42.06569877847699
# 3: 25.12294556385498
# 4: 15.095468210670576
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.983, TOP-5 ACCURACY - 59.679, BLEU-4 - 15.095468210670576
#
# Epoch validation time 52.371 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [17][0/118]	Batch Time 5.508 (5.508)	Data Load Time 4.103 (4.103)	Loss 3.8611 (3.8611)	Top-5 Accuracy 66.865 (66.865)
# Epoch: [17][100/118]	Batch Time 2.893 (2.133)	Data Load Time 1.565 (0.824)	Loss 3.9344 (3.9064)	Top-5 Accuracy 64.841 (66.065)
# Epoch train time 248.041 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.221 (5.221)	Loss 4.9486 (4.9486)	Top-5 Accuracy 59.574 (59.574)
# ----- Bleu-n Scores -----
# 1: 66.15254525160273
# 2: 42.1945393753461
# 3: 25.25893030248141
# 4: 15.212723516412229
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.983, TOP-5 ACCURACY - 59.711, BLEU-4 - 15.212723516412229
#
# Epoch validation time 52.444 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [18][0/118]	Batch Time 5.160 (5.160)	Data Load Time 3.700 (3.700)	Loss 3.8576 (3.8576)	Top-5 Accuracy 67.061 (67.061)
# Epoch: [18][100/118]	Batch Time 2.525 (2.137)	Data Load Time 1.300 (0.835)	Loss 3.8598 (3.9008)	Top-5 Accuracy 67.963 (66.114)
# Epoch train time 248.978 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.520 (5.520)	Loss 5.1645 (5.1645)	Top-5 Accuracy 58.020 (58.020)
# ----- Bleu-n Scores -----
# 1: 66.04186550428265
# 2: 42.08013275844303
# 3: 25.136570741232717
# 4: 15.086543789542345
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.982, TOP-5 ACCURACY - 59.721, BLEU-4 - 15.086543789542345
#
# Epoch validation time 52.680 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [19][0/118]	Batch Time 4.925 (4.925)	Data Load Time 3.486 (3.486)	Loss 3.8986 (3.8986)	Top-5 Accuracy 65.724 (65.724)
# Epoch: [19][100/118]	Batch Time 2.711 (2.122)	Data Load Time 1.457 (0.823)	Loss 3.9052 (3.9057)	Top-5 Accuracy 67.103 (66.043)
# Epoch train time 246.826 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 6.003 (6.003)	Loss 4.9327 (4.9327)	Top-5 Accuracy 60.814 (60.814)
# ----- Bleu-n Scores -----
# 1: 66.0928351220836
# 2: 42.11064082283392
# 3: 25.181222156015114
# 4: 15.147364804983459
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.982, TOP-5 ACCURACY - 59.736, BLEU-4 - 15.147364804983459
#
# Epoch validation time 52.946 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (2,)

# %%
m = load_checkpoint("BEST_checkpoint_flickr8k_tb.pth.tar")
# Out:
# Loaded Checkpoint!!
# Last Epoch: 17
# Best Bleu-4: 15.212723516412229

# %%
batch_size = 64
fine_tune_encoder = True
checkpoint = 'BEST_checkpoint_flickr8k_tb.pth.tar'
epochs = 30


t_params['data_name'] = t_params['data_name'] + "_finetune" 
t_params['fine_tune_encoder'] = True
t_params['epochs'] = epochs
t_params
# Out:
# {'data_name': 'flickr8k_tb_finetune',
#  'imgs_path': '../input/flickr8kimagescaptions/flickr8k/images/',
#  'df_path': '/kaggle/working/Image-Captioning/data.json',
#  'vocab': <dataset.Vocabulary at 0x7f0388ab1990>,
#  'epochs': 30,
#  'batch_size': 64,
#  'workers': 2,
#  'decoder_lr': 0.0004,
#  'encoder_lr': 0.0001,
#  'fine_tune_encoder': True,
#  'pretrained_embeddings': True,
#  'fine_tune_embeddings': True}

# %%
fit(t_params=t_params, checkpoint="BEST_checkpoint_flickr8k_tb.pth.tar", m_params=m_params, logger=logger)
# Out:
# Loaded Checkpoint!!
# Starting Epoch: 18
# Loading Data
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000
# __________________________________________________
# -------------------- Fitting --------------------
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [18][0/469]	Batch Time 4.009 (4.009)	Data Load Time 1.145 (1.145)	Loss 3.8489 (3.8489)	Top-5 Accuracy 67.468 (67.468)
# Epoch: [18][100/469]	Batch Time 0.723 (0.769)	Data Load Time 0.000 (0.012)	Loss 3.9696 (3.9997)	Top-5 Accuracy 65.306 (64.578)
# Epoch: [18][200/469]	Batch Time 0.734 (0.751)	Data Load Time 0.000 (0.006)	Loss 4.1231 (3.9676)	Top-5 Accuracy 64.549 (65.143)
# Epoch: [18][300/469]	Batch Time 0.774 (0.745)	Data Load Time 0.001 (0.004)	Loss 4.1054 (3.9527)	Top-5 Accuracy 62.667 (65.419)
# Epoch: [18][400/469]	Batch Time 0.711 (0.742)	Data Load Time 0.000 (0.003)	Loss 3.7707 (3.9388)	Top-5 Accuracy 70.112 (65.643)
# Epoch train time 347.899 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.415 (1.415)	Loss 5.0816 (5.0816)	Top-5 Accuracy 62.500 (62.500)
# ----- Bleu-n Scores -----
# 1: 66.35618539581647
# 2: 42.52919654997588
# 3: 25.431655792014208
# 4: 15.214512760400975
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.970, TOP-5 ACCURACY - 60.214, BLEU-4 - 15.214512760400975
#
# Epoch validation time 52.588 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [19][0/469]	Batch Time 1.822 (1.822)	Data Load Time 1.048 (1.048)	Loss 3.9934 (3.9934)	Top-5 Accuracy 64.981 (64.981)
# Epoch: [19][100/469]	Batch Time 0.731 (0.749)	Data Load Time 0.003 (0.011)	Loss 3.5875 (3.8183)	Top-5 Accuracy 71.244 (67.551)
# Epoch: [19][200/469]	Batch Time 0.728 (0.740)	Data Load Time 0.000 (0.006)	Loss 4.0552 (3.8191)	Top-5 Accuracy 62.466 (67.565)
# Epoch: [19][300/469]	Batch Time 0.717 (0.738)	Data Load Time 0.000 (0.004)	Loss 3.7135 (3.8221)	Top-5 Accuracy 69.380 (67.575)
# Epoch: [19][400/469]	Batch Time 0.717 (0.737)	Data Load Time 0.000 (0.003)	Loss 3.7831 (3.8211)	Top-5 Accuracy 67.524 (67.579)
# Epoch train time 345.411 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.512 (1.512)	Loss 5.2859 (5.2859)	Top-5 Accuracy 55.146 (55.146)
# ----- Bleu-n Scores -----
# 1: 66.65729667636671
# 2: 42.79163045430355
# 3: 25.683049746489743
# 4: 15.52506030413022
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.961, TOP-5 ACCURACY - 60.445, BLEU-4 - 15.52506030413022
#
# Epoch validation time 53.037 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [20][0/469]	Batch Time 1.715 (1.715)	Data Load Time 0.952 (0.952)	Loss 3.7957 (3.7957)	Top-5 Accuracy 67.880 (67.880)
# Epoch: [20][100/469]	Batch Time 0.735 (0.744)	Data Load Time 0.000 (0.010)	Loss 3.7199 (3.7586)	Top-5 Accuracy 71.198 (68.653)
# Epoch: [20][200/469]	Batch Time 0.760 (0.741)	Data Load Time 0.000 (0.005)	Loss 3.8935 (3.7655)	Top-5 Accuracy 66.753 (68.631)
# Epoch: [20][300/469]	Batch Time 0.750 (0.739)	Data Load Time 0.000 (0.004)	Loss 3.7793 (3.7688)	Top-5 Accuracy 69.147 (68.506)
# Epoch: [20][400/469]	Batch Time 0.718 (0.738)	Data Load Time 0.001 (0.003)	Loss 4.0496 (3.7675)	Top-5 Accuracy 64.124 (68.494)
# Epoch train time 345.782 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.473 (1.473)	Loss 5.2212 (5.2212)	Top-5 Accuracy 58.387 (58.387)
# ----- Bleu-n Scores -----
# 1: 66.5797065408652
# 2: 42.575810052509254
# 3: 25.326367409325083
# 4: 15.03134615206273
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.950, TOP-5 ACCURACY - 60.438, BLEU-4 - 15.03134615206273
#
# Epoch validation time 52.846 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [21][0/469]	Batch Time 1.862 (1.862)	Data Load Time 1.098 (1.098)	Loss 3.8516 (3.8516)	Top-5 Accuracy 66.026 (66.026)
# Epoch: [21][100/469]	Batch Time 0.766 (0.746)	Data Load Time 0.000 (0.011)	Loss 3.9275 (3.7231)	Top-5 Accuracy 66.626 (69.316)
# Epoch: [21][200/469]	Batch Time 0.751 (0.740)	Data Load Time 0.000 (0.006)	Loss 3.6640 (3.7147)	Top-5 Accuracy 69.588 (69.450)
# Epoch: [21][300/469]	Batch Time 0.728 (0.738)	Data Load Time 0.000 (0.004)	Loss 3.7464 (3.7189)	Top-5 Accuracy 68.260 (69.368)
# Epoch: [21][400/469]	Batch Time 0.704 (0.736)	Data Load Time 0.001 (0.003)	Loss 3.9147 (3.7271)	Top-5 Accuracy 66.252 (69.235)
# Epoch train time 344.993 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.587 (1.587)	Loss 5.2032 (5.2032)	Top-5 Accuracy 58.889 (58.889)
# ----- Bleu-n Scores -----
# 1: 66.83033044178507
# 2: 42.79064681450086
# 3: 25.452309402868917
# 4: 15.116537208361535
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.965, TOP-5 ACCURACY - 60.495, BLEU-4 - 15.116537208361535
#
# Epoch validation time 53.346 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (2,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [22][0/469]	Batch Time 1.703 (1.703)	Data Load Time 0.948 (0.948)	Loss 3.6452 (3.6452)	Top-5 Accuracy 68.229 (68.229)
# Epoch: [22][100/469]	Batch Time 0.703 (0.740)	Data Load Time 0.000 (0.010)	Loss 3.6852 (3.6499)	Top-5 Accuracy 70.225 (70.241)
# Epoch: [22][200/469]	Batch Time 0.847 (0.737)	Data Load Time 0.000 (0.005)	Loss 3.9422 (3.6728)	Top-5 Accuracy 66.457 (69.916)
# Epoch: [22][300/469]	Batch Time 0.720 (0.738)	Data Load Time 0.000 (0.004)	Loss 3.6264 (3.6857)	Top-5 Accuracy 69.189 (69.714)
# Epoch: [22][400/469]	Batch Time 0.724 (0.737)	Data Load Time 0.000 (0.003)	Loss 3.6903 (3.6859)	Top-5 Accuracy 69.856 (69.721)
# Epoch train time 344.553 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.047 (2.047)	Loss 5.4040 (5.4040)	Top-5 Accuracy 56.314 (56.314)
# ----- Bleu-n Scores -----
# 1: 66.28755622059911
# 2: 42.582535460567634
# 3: 25.536789597867138
# 4: 15.487548796137753
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.973, TOP-5 ACCURACY - 60.375, BLEU-4 - 15.487548796137753
#
# Epoch validation time 51.125 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (3,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [23][0/469]	Batch Time 1.770 (1.770)	Data Load Time 0.984 (0.984)	Loss 3.4007 (3.4007)	Top-5 Accuracy 72.215 (72.215)
# Epoch: [23][100/469]	Batch Time 0.698 (0.744)	Data Load Time 0.001 (0.010)	Loss 3.6068 (3.6318)	Top-5 Accuracy 70.891 (70.576)
# Epoch: [23][200/469]	Batch Time 0.712 (0.740)	Data Load Time 0.000 (0.006)	Loss 3.6099 (3.6415)	Top-5 Accuracy 71.272 (70.430)
# Epoch: [23][300/469]	Batch Time 0.724 (0.738)	Data Load Time 0.000 (0.004)	Loss 3.6961 (3.6483)	Top-5 Accuracy 70.365 (70.366)
# Epoch: [23][400/469]	Batch Time 0.714 (0.737)	Data Load Time 0.000 (0.003)	Loss 3.9383 (3.6576)	Top-5 Accuracy 66.937 (70.219)
# Epoch train time 345.071 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.447 (1.447)	Loss 5.0836 (5.0836)	Top-5 Accuracy 60.611 (60.611)
# ----- Bleu-n Scores -----
# 1: 66.41619425322249
# 2: 42.56598906783352
# 3: 25.682934557558205
# 4: 15.504209797381064
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.961, TOP-5 ACCURACY - 60.415, BLEU-4 - 15.504209797381064
#
# Epoch validation time 51.859 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (4,)
# Epoch     6: reducing learning rate of group 0 to 4.0000e-09.
# Epoch     6: reducing learning rate of group 0 to 1.0000e-05.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [24][0/469]	Batch Time 1.751 (1.751)	Data Load Time 1.014 (1.014)	Loss 3.5354 (3.5354)	Top-5 Accuracy 71.674 (71.674)
# Epoch: [24][100/469]	Batch Time 0.948 (0.751)	Data Load Time 0.003 (0.011)	Loss 3.7839 (3.5826)	Top-5 Accuracy 67.591 (71.212)
# Epoch: [24][200/469]	Batch Time 0.709 (0.743)	Data Load Time 0.000 (0.006)	Loss 3.3220 (3.5749)	Top-5 Accuracy 74.422 (71.356)
# Epoch: [24][300/469]	Batch Time 0.719 (0.740)	Data Load Time 0.000 (0.004)	Loss 3.6087 (3.5802)	Top-5 Accuracy 71.854 (71.372)
# Epoch: [24][400/469]	Batch Time 0.702 (0.739)	Data Load Time 0.000 (0.003)	Loss 3.5802 (3.5794)	Top-5 Accuracy 68.811 (71.354)
# Epoch train time 346.187 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.448 (1.448)	Loss 4.5187 (4.5187)	Top-5 Accuracy 63.445 (63.445)
# ----- Bleu-n Scores -----
# 1: 66.71194419842578
# 2: 42.78977465674878
# 3: 25.720548581270116
# 4: 15.533793671583021
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.955, TOP-5 ACCURACY - 60.673, BLEU-4 - 15.533793671583021
#
# Epoch validation time 53.243 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [25][0/469]	Batch Time 2.413 (2.413)	Data Load Time 1.630 (1.630)	Loss 3.5308 (3.5308)	Top-5 Accuracy 70.385 (70.385)
# Epoch: [25][100/469]	Batch Time 0.734 (0.757)	Data Load Time 0.000 (0.017)	Loss 3.6015 (3.5575)	Top-5 Accuracy 72.409 (71.794)
# Epoch: [25][200/469]	Batch Time 0.733 (0.746)	Data Load Time 0.000 (0.009)	Loss 3.6845 (3.5505)	Top-5 Accuracy 69.036 (71.884)
# Epoch: [25][300/469]	Batch Time 0.715 (0.741)	Data Load Time 0.000 (0.006)	Loss 3.5934 (3.5508)	Top-5 Accuracy 72.483 (71.871)
# Epoch: [25][400/469]	Batch Time 0.748 (0.740)	Data Load Time 0.000 (0.005)	Loss 3.6308 (3.5503)	Top-5 Accuracy 70.066 (71.877)
# Epoch train time 346.224 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.391 (1.391)	Loss 5.2892 (5.2892)	Top-5 Accuracy 56.607 (56.607)
# ----- Bleu-n Scores -----
# 1: 66.66367897911732
# 2: 42.78452893516918
# 3: 25.72884579370754
# 4: 15.533743077358553
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.958, TOP-5 ACCURACY - 60.673, BLEU-4 - 15.533743077358553
#
# Epoch validation time 52.748 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [26][0/469]	Batch Time 1.733 (1.733)	Data Load Time 0.990 (0.990)	Loss 3.5221 (3.5221)	Top-5 Accuracy 70.822 (70.822)
# Epoch: [26][100/469]	Batch Time 0.731 (0.747)	Data Load Time 0.000 (0.010)	Loss 3.6398 (3.5404)	Top-5 Accuracy 70.755 (71.965)
# Epoch: [26][200/469]	Batch Time 0.775 (0.739)	Data Load Time 0.000 (0.005)	Loss 3.6389 (3.5452)	Top-5 Accuracy 71.750 (71.965)
# Epoch: [26][300/469]	Batch Time 0.736 (0.737)	Data Load Time 0.000 (0.004)	Loss 3.5783 (3.5380)	Top-5 Accuracy 71.133 (72.066)
# Epoch: [26][400/469]	Batch Time 0.717 (0.737)	Data Load Time 0.000 (0.003)	Loss 3.4455 (3.5360)	Top-5 Accuracy 72.142 (72.091)
# Epoch train time 345.468 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.582 (1.582)	Loss 4.5448 (4.5448)	Top-5 Accuracy 64.032 (64.032)
# ----- Bleu-n Scores -----
# 1: 66.74511012121883
# 2: 42.8583802710239
# 3: 25.681186654367234
# 4: 15.405972417231997
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.959, TOP-5 ACCURACY - 60.625, BLEU-4 - 15.405972417231997
#
# Epoch validation time 52.620 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (2,)
# Epoch     9: reducing learning rate of group 0 to 1.0000e-06.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [27][0/469]	Batch Time 2.083 (2.083)	Data Load Time 1.347 (1.347)	Loss 3.6590 (3.6590)	Top-5 Accuracy 70.115 (70.115)
# Epoch: [27][100/469]	Batch Time 0.713 (0.749)	Data Load Time 0.000 (0.014)	Loss 3.5185 (3.5229)	Top-5 Accuracy 71.488 (72.316)
# Epoch: [27][200/469]	Batch Time 0.775 (0.743)	Data Load Time 0.000 (0.007)	Loss 3.5186 (3.5163)	Top-5 Accuracy 73.205 (72.359)
# Epoch: [27][300/469]	Batch Time 0.740 (0.742)	Data Load Time 0.000 (0.005)	Loss 3.3740 (3.5183)	Top-5 Accuracy 75.278 (72.264)
# Epoch: [27][400/469]	Batch Time 0.750 (0.742)	Data Load Time 0.000 (0.004)	Loss 3.4868 (3.5182)	Top-5 Accuracy 74.028 (72.283)
# Epoch train time 346.833 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.486 (1.486)	Loss 5.2010 (5.2010)	Top-5 Accuracy 61.667 (61.667)
# ----- Bleu-n Scores -----
# 1: 66.79723454706482
# 2: 42.909635260999714
# 3: 25.73375876673812
# 4: 15.456141023252409
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.962, TOP-5 ACCURACY - 60.602, BLEU-4 - 15.456141023252409
#
# Epoch validation time 51.806 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (3,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [28][0/469]	Batch Time 1.795 (1.795)	Data Load Time 1.045 (1.045)	Loss 3.7410 (3.7410)	Top-5 Accuracy 69.143 (69.143)
# Epoch: [28][100/469]	Batch Time 0.720 (0.743)	Data Load Time 0.001 (0.011)	Loss 3.3419 (3.5009)	Top-5 Accuracy 76.439 (72.597)
# Epoch: [28][200/469]	Batch Time 0.711 (0.739)	Data Load Time 0.000 (0.006)	Loss 3.4041 (3.5132)	Top-5 Accuracy 73.190 (72.465)
# Epoch: [28][300/469]	Batch Time 0.733 (0.737)	Data Load Time 0.000 (0.004)	Loss 3.5175 (3.5106)	Top-5 Accuracy 72.178 (72.484)
# Epoch: [28][400/469]	Batch Time 0.728 (0.737)	Data Load Time 0.000 (0.003)	Loss 3.7703 (3.5130)	Top-5 Accuracy 68.724 (72.410)
# Epoch train time 345.225 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.480 (1.480)	Loss 5.3841 (5.3841)	Top-5 Accuracy 60.182 (60.182)
# ----- Bleu-n Scores -----
# 1: 66.78648565822947
# 2: 42.88071137364193
# 3: 25.67567833347867
# 4: 15.380491638002855
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.962, TOP-5 ACCURACY - 60.663, BLEU-4 - 15.380491638002855
#
# Epoch validation time 51.352 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (4,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [29][0/469]	Batch Time 1.728 (1.728)	Data Load Time 0.966 (0.966)	Loss 3.4422 (3.4422)	Top-5 Accuracy 72.215 (72.215)
# Epoch: [29][100/469]	Batch Time 0.721 (0.748)	Data Load Time 0.000 (0.010)	Loss 3.4174 (3.5072)	Top-5 Accuracy 74.901 (72.549)
# Epoch: [29][200/469]	Batch Time 0.734 (0.740)	Data Load Time 0.000 (0.005)	Loss 3.4085 (3.5145)	Top-5 Accuracy 73.859 (72.448)
# Epoch: [29][300/469]	Batch Time 0.711 (0.739)	Data Load Time 0.000 (0.004)	Loss 3.5381 (3.5165)	Top-5 Accuracy 73.562 (72.358)
# Epoch: [29][400/469]	Batch Time 0.752 (0.738)	Data Load Time 0.000 (0.003)	Loss 3.3728 (3.5169)	Top-5 Accuracy 74.365 (72.389)
# Epoch train time 345.730 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.492 (1.492)	Loss 4.7114 (4.7114)	Top-5 Accuracy 59.896 (59.896)
# ----- Bleu-n Scores -----
# 1: 66.656848820156
# 2: 42.831978496787634
# 3: 25.611922748782632
# 4: 15.343361506767266
# -------------------------
# ----- METEOR Score -----
#
#  * LOSS - 4.962, TOP-5 ACCURACY - 60.623, BLEU-4 - 15.343361506767266
#
# Epoch validation time 51.879 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (5,)
# No improvement for 3 consecutive epochs, terminating...

# %%
m = load_checkpoint("BEST_checkpoint_flickr8k_tb.pth.tar")
# Out:
# Loaded Checkpoint!!
# Last Epoch: 17
# Best Bleu-4: 15.212723516412229

# %%
m = load_checkpoint("BEST_checkpoint_flickr8k_tb_finetune.pth.tar")
# Out:
# Loaded Checkpoint!!
# Last Epoch: 24
# Best Bleu-4: 15.533793671583021

# %%
# !ls
# Out:
# BEST_checkpoint_flickr8k_tb.pth.tar
# BEST_checkpoint_flickr8k_tb_finetune.pth.tar
# Image-Captioning
# __notebook_source__.ipynb
# checkpoint_flickr8k_tb.pth.tar
# checkpoint_flickr8k_tb_finetune.pth.tar
# experiments

# %%
# !zip -r pre_trained.zip BEST_checkpoint_flickr8k_tb_finetune.pth.tar experiments
# Out:
#   adding: BEST_checkpoint_flickr8k_tb_finetune.pth.tar (deflated 9%)
#   adding: experiments/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/events.out.tfevents.1624444330.49c0fa9f8e04.42.0 (deflated 69%)

# %%
# !zip -r experiemnts_pretrained.zip experiments
# Out:
#   adding: experiments/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/events.out.tfevents.1624444330.49c0fa9f8e04.42.0 (deflated 69%)

# %%
from IPython.display import FileLink
FileLink('experiemnts_pretrained.zip')
# Out:
# /kaggle/working/experiemnts_pretrained.zip

# %%
checkpoint = load_checkpoint("BEST_checkpoint_flickr8k_tb_finetune.pth.tar")
decoder = checkpoint['decoder']
decoder = decoder.to(device)
decoder.eval()
encoder = checkpoint['encoder']
encoder = encoder.to(device)
encoder.eval();
# Out:
# Loaded Checkpoint!!
# Last Epoch: 24
# Best Bleu-4: 15.533793671583021

# %%
from eval import test_score

b1, b2, b3, b4 = test_score(1, encoder, decoder, IMGS_PATH, DATA_JSON_PATH, vocab)
# Out:
# EVALUATING AT BEAM SIZE 1:   0%|          | 0/5000 [00:00<?, ?it/s]
# Dataset split: test
# Unique images: 1000
# Total size: 5000
# EVALUATING AT BEAM SIZE 1: 100%|██████████| 5000/5000 [04:07<00:00, 20.21it/s]
# ----- Bleu-n Scores -----
# 1: 60.712287898564234
# 2: 43.53202026800945
# 3: 29.852698297065306
# 4: 20.294859174878876
# -------------------------

# %%
test_dict = {}

for i in [1, 3, 5]:
    
    b1, b2, b3, b4 = test_score(i, encoder, decoder, IMGS_PATH, DATA_JSON_PATH, vocab)
    if i == 3:
        test_dict['b1'] = b1
        test_dict['b2'] = b2
        test_dict['b3'] = b3
    
    test_dict[f'b4-b{i}'] = b4
# Out:
# EVALUATING AT BEAM SIZE 1:   0%|          | 0/5000 [00:00<?, ?it/s]
# Dataset split: test
# Unique images: 1000
# Total size: 5000
# EVALUATING AT BEAM SIZE 1: 100%|██████████| 5000/5000 [04:09<00:00, 20.01it/s]
# ----- Bleu-n Scores -----
# 1: 60.712287898564234
# 2: 43.53202026800945
# 3: 29.852698297065306
# 4: 20.294859174878876
# -------------------------
# EVALUATING AT BEAM SIZE 3:   0%|          | 0/5000 [00:00<?, ?it/s]
# Dataset split: test
# Unique images: 1000
# Total size: 5000
# EVALUATING AT BEAM SIZE 3: 100%|██████████| 5000/5000 [04:31<00:00, 18.39it/s]
# ----- Bleu-n Scores -----
# 1: 63.953949980150846
# 2: 46.48314296326771
# 3: 32.935330253964565
# 4: 22.739269233648933
# -------------------------
# EVALUATING AT BEAM SIZE 5:   0%|          | 0/5000 [00:00<?, ?it/s]
# Dataset split: test
# Unique images: 1000
# Total size: 5000
# EVALUATING AT BEAM SIZE 5: 100%|██████████| 5000/5000 [04:46<00:00, 17.46it/s]
# ----- Bleu-n Scores -----
# 1: 65.16982704730152
# 2: 47.3396422938947
# 3: 33.53530794815447
# 4: 23.23361748348483
# -------------------------

# %%
test_dict
# Out:
# {'b4-b1': 20.294859174878876,
#  'b1': 63.953949980150846,
#  'b2': 46.48314296326771,
#  'b3': 32.935330253964565,
#  'b4-b3': 22.739269233648933,
#  'b4-b5': 23.23361748348483}

# %%
# final results -> different from training and validation scalars
results_dic =  {
    # train & valid
    'total_epochs': 2,
    'top5acc/valid/1': 58.8,
    'b-1/test': test_dict['b1'],
    'b-2/test': test_dict['b2'],
    'b-3/test': test_dict['b3'],
    'b-4/b3': test_dict['b4-b3'],
    'b-4/b1': test_dict['b4-b1'],
    'b-4/b5': test_dict['b4-b5']
}

# %%
logger.add_hparams(logger_dic, results_dic, run_name='finetune')

# %%
# !ls
# Out:
# BEST_checkpoint_flickr8k_tb.pth.tar
# BEST_checkpoint_flickr8k_tb_finetune.pth.tar
# Image-Captioning
# __notebook_source__.ipynb
# checkpoint_flickr8k_tb.pth.tar
# checkpoint_flickr8k_tb_finetune.pth.tar
# experiemnts_pretrained.zip
# experiments
# pre_trained.zip

# %%
# !zip -r pre_trained_exp.zip experiments
# Out:
#   adding: experiments/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/finetune/ (stored 0%)
#   adding: experiments/flickr8k_tb_pretrained_glove/finetune/events.out.tfevents.1624461312.49c0fa9f8e04.42.1 (deflated 45%)
#   adding: experiments/flickr8k_tb_pretrained_glove/events.out.tfevents.1624444330.49c0fa9f8e04.42.0 (deflated 69%)

# %%
from IPython.display import FileLink
FileLink('pre_trained_exp.zip')
# Out:
# /kaggle/working/pre_trained_exp.zip
