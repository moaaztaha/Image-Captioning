# %%
# get the code for kaggle
# !git clone https://github.com/moaaztaha/Image-Captioning
py_files_path = '/kaggle/working/Image-Captioning/'
import sys
sys.path.append(py_files_path)
# Out:
# Cloning into 'Image-Captioning'...
# remote: Enumerating objects: 298, done.
# remote: Counting objects: 100% (298/298), done.
# remote: Compressing objects: 100% (221/221), done.
# remote: Total 298 (delta 176), reused 194 (delta 74), pack-reused 0
# Receiving objects: 100% (298/298), 14.74 MiB | 14.86 MiB/s, done.
# Resolving deltas: 100% (176/176), done.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import time 
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence
from models import Encoder, DecoderWithAttention
from dataset import *
from utils import *
from train import *
from nltk.translate.bleu_score import corpus_bleu

# %%
# Model parameters
encoder_dim = 2048 # resnet101
emb_dim = 512  # dimension of word embeddings
attention_dim = 512  # dimension of attention linear layers
decoder_dim = 512  # dimension of decoder RNN
dropout = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # sets device for model and PyTorch tensors
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# training parameters
epochs = 6  # number of epochs to train for (if early stopping is not triggered)
batch_size = 64
workers = 4
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning
decoder_lr = 4e-4  # learning rate for decoder
fine_tune_encoder = True  # fine-tune encoder?
checkpoint = None  # path to checkpoint, None if none

# %%
DATA_NAME = 'flickr8k_5_cap_per_img_2_min_word_freq_resnet101_finetunefromthestart'

# local
# DATA_JSON_PATH = 'data.json'
# IMGS_PATH = 'flickr/Images/'
# kaggle paths
DATA_JSON_PATH = '/kaggle/working/Image-Captioning/data.json'
IMGS_PATH = '../input/flickr8kimagescaptions/flickr8k/images/'

# %%
# load vocab
vocab = build_vocab(DATA_JSON_PATH)
# Out:
# 100%|██████████| 30000/30000 [00:00<00:00, 223533.68it/s]

# %%
len(vocab)
# Out:
# 4451

# %%
t_params = {
    'data_name': DATA_NAME,
    'imgs_path': IMGS_PATH,
    'df_path': DATA_JSON_PATH,
    'vocab': vocab,
    'epochs': epochs,
    'batch_size': batch_size,
    'workers': workers,
    'decoder_lr': decoder_lr,
    'encoder_lr': encoder_lr,
    'fine_tune_encoder': fine_tune_encoder
}

m_params = {
    'attention_dim': attention_dim,
    'embed_dim': emb_dim,
    'decoder_dim': decoder_dim,
    'encoder_dim': encoder_dim,
    'dropout': dropout
}

# %%
t_params
# Out:
# {'data_name': 'flickr8k_5_cap_per_img_2_min_word_freq_resnet101_finetunefromthestart',
#  'imgs_path': '../input/flickr8kimagescaptions/flickr8k/images/',
#  'df_path': '/kaggle/working/Image-Captioning/data.json',
#  'vocab': <dataset.Vocabulary at 0x7f6e3b0fcc90>,
#  'epochs': 6,
#  'batch_size': 64,
#  'workers': 4,
#  'decoder_lr': 0.0004,
#  'encoder_lr': 0.0001,
#  'fine_tune_encoder': True}

# %%
fit(t_params=t_params, m_params=m_params)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
#   0%|          | 0.00/170M [00:00<?, ?B/s]
# Loading Data
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000
# __________________________________________________
# -------------------- Fitting --------------------
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [0][0/469]	Batch Time 6.150 (6.150)	Data Load Time 2.252 (2.252)	Loss 9.3009 (9.3009)	Top-5 Accuracy 0.000 (0.000)
# Epoch: [0][100/469]	Batch Time 0.685 (0.777)	Data Load Time 0.000 (0.023)	Loss 5.6434 (6.2207)	Top-5 Accuracy 42.301 (35.474)
# Epoch: [0][200/469]	Batch Time 0.753 (0.748)	Data Load Time 0.000 (0.012)	Loss 4.9385 (5.7774)	Top-5 Accuracy 55.918 (41.256)
# Epoch: [0][300/469]	Batch Time 0.712 (0.737)	Data Load Time 0.000 (0.008)	Loss 4.9255 (5.5053)	Top-5 Accuracy 51.216 (45.052)
# Epoch: [0][400/469]	Batch Time 0.716 (0.732)	Data Load Time 0.000 (0.006)	Loss 4.8176 (5.3192)	Top-5 Accuracy 55.140 (47.666)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.645 (2.645)	Loss 5.5559 (5.5559)	Top-5 Accuracy 50.687 (50.687)
# ----- Bleu-n Scores -----
# 1: 56.90828097650847
# 2: 35.014961154773054
# 3: 20.12553025994983
# 4: 11.379098813864411
# -------------------------
#
#  * LOSS - 5.449, TOP-5 ACCURACY - 52.092, BLEU-4 - 0.1145365438837766
#
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [1][0/469]	Batch Time 3.601 (3.601)	Data Load Time 2.521 (2.521)	Loss 4.6645 (4.6645)	Top-5 Accuracy 57.165 (57.165)
# Epoch: [1][100/469]	Batch Time 0.765 (0.753)	Data Load Time 0.000 (0.025)	Loss 4.4648 (4.4517)	Top-5 Accuracy 58.671 (59.467)
# Epoch: [1][200/469]	Batch Time 0.688 (0.735)	Data Load Time 0.000 (0.013)	Loss 4.1690 (4.4078)	Top-5 Accuracy 61.807 (60.073)
# Epoch: [1][300/469]	Batch Time 0.812 (0.729)	Data Load Time 0.000 (0.009)	Loss 4.1531 (4.3730)	Top-5 Accuracy 62.558 (60.431)
# Epoch: [1][400/469]	Batch Time 0.697 (0.725)	Data Load Time 0.000 (0.007)	Loss 4.2160 (4.3414)	Top-5 Accuracy 63.693 (60.878)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.734 (2.734)	Loss 5.5535 (5.5535)	Top-5 Accuracy 52.229 (52.229)
# ----- Bleu-n Scores -----
# 1: 59.18003250221089
# 2: 37.034239400449955
# 3: 22.11310165620341
# 4: 12.960223218113445
# -------------------------
#
#  * LOSS - 5.295, TOP-5 ACCURACY - 55.662, BLEU-4 - 0.13045137559028167
#
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [2][0/469]	Batch Time 3.071 (3.071)	Data Load Time 2.089 (2.089)	Loss 4.1813 (4.1813)	Top-5 Accuracy 64.648 (64.648)
# Epoch: [2][100/469]	Batch Time 0.693 (0.744)	Data Load Time 0.000 (0.021)	Loss 4.2375 (4.0497)	Top-5 Accuracy 63.285 (64.588)
# Epoch: [2][200/469]	Batch Time 0.723 (0.729)	Data Load Time 0.000 (0.011)	Loss 3.9189 (4.0319)	Top-5 Accuracy 67.758 (64.814)
# Epoch: [2][300/469]	Batch Time 0.690 (0.726)	Data Load Time 0.000 (0.007)	Loss 3.8458 (4.0222)	Top-5 Accuracy 68.949 (65.007)
# Epoch: [2][400/469]	Batch Time 0.703 (0.723)	Data Load Time 0.000 (0.005)	Loss 3.6834 (4.0059)	Top-5 Accuracy 71.082 (65.285)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.666 (2.666)	Loss 4.8780 (4.8780)	Top-5 Accuracy 57.704 (57.704)
# ----- Bleu-n Scores -----
# 1: 59.541581910495566
# 2: 37.09320386633071
# 3: 22.114150465128976
# 4: 12.894054077041945
# -------------------------
#
#  * LOSS - 5.217, TOP-5 ACCURACY - 57.156, BLEU-4 - 0.12978531927462145
#
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [3][0/469]	Batch Time 2.934 (2.934)	Data Load Time 2.111 (2.111)	Loss 3.7917 (3.7917)	Top-5 Accuracy 68.709 (68.709)
# Epoch: [3][100/469]	Batch Time 0.682 (0.747)	Data Load Time 0.000 (0.021)	Loss 3.8365 (3.7951)	Top-5 Accuracy 68.081 (67.872)
# Epoch: [3][200/469]	Batch Time 0.722 (0.732)	Data Load Time 0.000 (0.011)	Loss 3.9059 (3.7928)	Top-5 Accuracy 65.356 (68.015)
# Epoch: [3][300/469]	Batch Time 0.667 (0.725)	Data Load Time 0.000 (0.007)	Loss 3.6142 (3.7813)	Top-5 Accuracy 72.043 (68.188)
# Epoch: [3][400/469]	Batch Time 0.709 (0.722)	Data Load Time 0.000 (0.006)	Loss 3.7958 (3.7789)	Top-5 Accuracy 68.000 (68.230)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.592 (2.592)	Loss 5.2671 (5.2671)	Top-5 Accuracy 58.609 (58.609)
# ----- Bleu-n Scores -----
# 1: 59.6641113320204
# 2: 37.668319310879596
# 3: 22.57412095915959
# 4: 13.174999308757085
# -------------------------
#
#  * LOSS - 5.243, TOP-5 ACCURACY - 57.932, BLEU-4 - 0.13261318032932337
#
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [4][0/469]	Batch Time 3.393 (3.393)	Data Load Time 2.469 (2.469)	Loss 3.6705 (3.6705)	Top-5 Accuracy 70.717 (70.717)
# Epoch: [4][100/469]	Batch Time 0.723 (0.742)	Data Load Time 0.000 (0.025)	Loss 3.5617 (3.5733)	Top-5 Accuracy 73.354 (70.982)
# Epoch: [4][200/469]	Batch Time 0.692 (0.727)	Data Load Time 0.000 (0.013)	Loss 3.5471 (3.5823)	Top-5 Accuracy 72.313 (70.866)
# Epoch: [4][300/469]	Batch Time 0.699 (0.722)	Data Load Time 0.000 (0.008)	Loss 3.6438 (3.5918)	Top-5 Accuracy 70.048 (70.742)
# Epoch: [4][400/469]	Batch Time 0.706 (0.719)	Data Load Time 0.000 (0.006)	Loss 3.6585 (3.5940)	Top-5 Accuracy 67.969 (70.724)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.497 (2.497)	Loss 5.2040 (5.2040)	Top-5 Accuracy 58.165 (58.165)
# ----- Bleu-n Scores -----
# 1: 59.89510043900731
# 2: 37.82653677489215
# 3: 22.87869792504663
# 4: 13.545351577261943
# -------------------------
#
#  * LOSS - 5.251, TOP-5 ACCURACY - 58.586, BLEU-4 - 0.13634096537364324
#
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [5][0/469]	Batch Time 2.981 (2.981)	Data Load Time 1.907 (1.907)	Loss 3.2831 (3.2831)	Top-5 Accuracy 75.117 (75.117)
# Epoch: [5][100/469]	Batch Time 0.734 (0.741)	Data Load Time 0.000 (0.019)	Loss 3.4542 (3.4282)	Top-5 Accuracy 73.516 (72.906)
# Epoch: [5][200/469]	Batch Time 0.716 (0.726)	Data Load Time 0.000 (0.010)	Loss 3.7083 (3.4437)	Top-5 Accuracy 68.612 (72.676)
# Epoch: [5][300/469]	Batch Time 0.848 (0.722)	Data Load Time 0.000 (0.007)	Loss 3.4874 (3.4452)	Top-5 Accuracy 74.286 (72.738)
# Epoch: [5][400/469]	Batch Time 0.707 (0.721)	Data Load Time 0.000 (0.005)	Loss 3.4022 (3.4496)	Top-5 Accuracy 72.985 (72.711)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.437 (2.437)	Loss 5.7587 (5.7587)	Top-5 Accuracy 54.173 (54.173)
# ----- Bleu-n Scores -----
# 1: 59.7886441926357
# 2: 37.65420105848561
# 3: 22.6705200554531
# 4: 13.322483247955855
# -------------------------
#
#  * LOSS - 5.269, TOP-5 ACCURACY - 58.802, BLEU-4 - 0.1340976909635772
#
#
# Epochs since last improvement: (1,)

# %%
checkpoint = load_checkpoint('./BEST_checkpoint_flickr8k_5_cap_per_img_2_min_word_freq_resnet101_finetunefromthestart.pth.tar')
# Out:
# Loaded Checkpoint!!
# Last Epoch: 4
# Best Bleu-4: 0.13634096537364324

# %%
# parameters
epochs = 10  
batch_size = 64
workers = 4
encoder_lr = 1e-5 * .8
decoder_lr = 3e-4 * .8
fine_tune_encoder = True  
checkpoint = './BEST_checkpoint_flickr8k_5_cap_per_img_2_min_word_freq_resnet101_finetunefromthestart.pth.tar'  # path to checkpoint, None if none

# %%
t_params = {
    'data_name': DATA_NAME,
    'imgs_path': IMGS_PATH,
    'df_path': DATA_JSON_PATH,
    'vocab': vocab,
    'epochs': epochs,
    'batch_size': batch_size,
    'workers': workers,
    'decoder_lr': decoder_lr,
    'encoder_lr': encoder_lr,
    'fine_tune_encoder': fine_tune_encoder
}

# %%
t_params
# Out:
# {'data_name': 'flickr8k_5_cap_per_img_2_min_word_freq_resnet101_finetunefromthestart',
#  'imgs_path': '../input/flickr8kimagescaptions/flickr8k/images/',
#  'df_path': '/kaggle/working/Image-Captioning/data.json',
#  'vocab': <dataset.Vocabulary at 0x7f6e3b0fcc90>,
#  'epochs': 10,
#  'batch_size': 64,
#  'workers': 4,
#  'decoder_lr': 0.00023999999999999998,
#  'encoder_lr': 8.000000000000001e-06,
#  'fine_tune_encoder': True}

# %%
fit(t_params, checkpoint, m_params)
# Out:
# Loaded Checkpoint!!
# Starting Epoch: 5
# Loading Data
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000
# __________________________________________________
# -------------------- Fitting --------------------
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [5][0/469]	Batch Time 2.652 (2.652)	Data Load Time 1.821 (1.821)	Loss 3.3510 (3.3510)	Top-5 Accuracy 73.906 (73.906)
# Epoch: [5][100/469]	Batch Time 0.713 (0.735)	Data Load Time 0.000 (0.018)	Loss 3.3715 (3.4215)	Top-5 Accuracy 73.708 (73.025)
# Epoch: [5][200/469]	Batch Time 0.753 (0.727)	Data Load Time 0.000 (0.009)	Loss 3.2441 (3.4304)	Top-5 Accuracy 77.097 (73.028)
# Epoch: [5][300/469]	Batch Time 0.720 (0.722)	Data Load Time 0.000 (0.006)	Loss 3.7493 (3.4386)	Top-5 Accuracy 69.679 (72.877)
# Epoch: [5][400/469]	Batch Time 0.680 (0.720)	Data Load Time 0.000 (0.005)	Loss 3.2901 (3.4456)	Top-5 Accuracy 75.043 (72.777)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 3.428 (3.428)	Loss 5.2619 (5.2619)	Top-5 Accuracy 56.935 (56.935)
# ----- Bleu-n Scores -----
# 1: 59.71633202785729
# 2: 37.47441951218299
# 3: 22.618286517057932
# 4: 13.377847516667622
# -------------------------
#
#  * LOSS - 5.271, TOP-5 ACCURACY - 58.744, BLEU-4 - 0.13465495449597473
#
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [6][0/469]	Batch Time 2.715 (2.715)	Data Load Time 1.813 (1.813)	Loss 3.2489 (3.2489)	Top-5 Accuracy 76.651 (76.651)
# Epoch: [6][100/469]	Batch Time 0.712 (0.743)	Data Load Time 0.000 (0.018)	Loss 3.2599 (3.2940)	Top-5 Accuracy 75.043 (74.828)
# Epoch: [6][200/469]	Batch Time 0.739 (0.728)	Data Load Time 0.000 (0.009)	Loss 3.5463 (3.3022)	Top-5 Accuracy 69.632 (74.749)
# Epoch: [6][300/469]	Batch Time 0.684 (0.724)	Data Load Time 0.000 (0.006)	Loss 3.4399 (3.3064)	Top-5 Accuracy 72.683 (74.736)
# Epoch: [6][400/469]	Batch Time 0.713 (0.721)	Data Load Time 0.000 (0.005)	Loss 3.4561 (3.3161)	Top-5 Accuracy 74.924 (74.652)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.631 (2.631)	Loss 5.3835 (5.3835)	Top-5 Accuracy 58.469 (58.469)
# ----- Bleu-n Scores -----
# 1: 60.286781342900575
# 2: 38.10654449985341
# 3: 23.204853242732927
# 4: 13.826031396106126
# -------------------------
#
#  * LOSS - 5.299, TOP-5 ACCURACY - 58.976, BLEU-4 - 0.13916614323948495
#
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [7][0/469]	Batch Time 2.983 (2.983)	Data Load Time 1.885 (1.885)	Loss 3.0676 (3.0676)	Top-5 Accuracy 79.487 (79.487)
# Epoch: [7][100/469]	Batch Time 0.702 (0.739)	Data Load Time 0.000 (0.019)	Loss 3.1493 (3.1450)	Top-5 Accuracy 76.593 (76.927)
# Epoch: [7][200/469]	Batch Time 0.818 (0.725)	Data Load Time 0.000 (0.010)	Loss 3.4297 (3.1685)	Top-5 Accuracy 71.084 (76.692)
# Epoch: [7][300/469]	Batch Time 0.690 (0.721)	Data Load Time 0.000 (0.007)	Loss 3.1448 (3.1815)	Top-5 Accuracy 77.913 (76.509)
# Epoch: [7][400/469]	Batch Time 0.705 (0.719)	Data Load Time 0.000 (0.005)	Loss 3.1154 (3.1900)	Top-5 Accuracy 76.853 (76.360)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.649 (2.649)	Loss 5.5496 (5.5496)	Top-5 Accuracy 54.221 (54.221)
# ----- Bleu-n Scores -----
# 1: 59.44717483768517
# 2: 37.29341649589359
# 3: 22.490836968763904
# 4: 13.307184907151742
# -------------------------
#
#  * LOSS - 5.319, TOP-5 ACCURACY - 59.457, BLEU-4 - 0.13394370287594656
#
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [8][0/469]	Batch Time 2.826 (2.826)	Data Load Time 1.950 (1.950)	Loss 3.0802 (3.0802)	Top-5 Accuracy 78.469 (78.469)
# Epoch: [8][100/469]	Batch Time 0.718 (0.738)	Data Load Time 0.000 (0.020)	Loss 3.1568 (3.0240)	Top-5 Accuracy 76.970 (78.876)
# Epoch: [8][200/469]	Batch Time 0.722 (0.724)	Data Load Time 0.000 (0.010)	Loss 3.1419 (3.0495)	Top-5 Accuracy 76.282 (78.562)
# Epoch: [8][300/469]	Batch Time 0.700 (0.720)	Data Load Time 0.000 (0.007)	Loss 3.1799 (3.0658)	Top-5 Accuracy 74.923 (78.269)
# Epoch: [8][400/469]	Batch Time 0.716 (0.718)	Data Load Time 0.000 (0.005)	Loss 3.3355 (3.0824)	Top-5 Accuracy 73.556 (77.981)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.481 (2.481)	Loss 5.3007 (5.3007)	Top-5 Accuracy 58.576 (58.576)
# ----- Bleu-n Scores -----
# 1: 59.640007277094256
# 2: 37.21026521193338
# 3: 22.329457381514537
# 4: 13.070176921187882
# -------------------------
#
#  * LOSS - 5.410, TOP-5 ACCURACY - 58.928, BLEU-4 - 0.13155808614034278
#
#
# Epochs since last improvement: (2,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [9][0/469]	Batch Time 2.733 (2.733)	Data Load Time 1.897 (1.897)	Loss 3.0354 (3.0354)	Top-5 Accuracy 77.903 (77.903)
# Epoch: [9][100/469]	Batch Time 0.690 (0.739)	Data Load Time 0.000 (0.019)	Loss 2.8852 (2.9383)	Top-5 Accuracy 80.314 (79.940)
# Epoch: [9][200/469]	Batch Time 0.729 (0.726)	Data Load Time 0.000 (0.010)	Loss 2.9969 (2.9476)	Top-5 Accuracy 80.085 (79.902)
# Epoch: [9][300/469]	Batch Time 0.713 (0.722)	Data Load Time 0.000 (0.007)	Loss 3.1236 (2.9612)	Top-5 Accuracy 75.857 (79.681)
# Epoch: [9][400/469]	Batch Time 0.702 (0.720)	Data Load Time 0.000 (0.005)	Loss 3.0112 (2.9734)	Top-5 Accuracy 78.995 (79.538)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 2.504 (2.504)	Loss 5.4268 (5.4268)	Top-5 Accuracy 59.804 (59.804)
# ----- Bleu-n Scores -----
# 1: 59.850910622943346
# 2: 37.48259594094967
# 3: 22.736425210604562
# 4: 13.600982685795588
# -------------------------
#
#  * LOSS - 5.435, TOP-5 ACCURACY - 59.012, BLEU-4 - 0.13690094071055864
#
#
# Epochs since last improvement: (3,)

# %%
checkpoint = load_checkpoint('./BEST_checkpoint_flickr8k_5_cap_per_img_2_min_word_freq_resnet101_finetunefromthestart.pth.tar')
# Out:
# Loaded Checkpoint!!
# Last Epoch: 6
# Best Bleu-4: 0.13916614323948495

# %% [markdown]
# <a href='./BEST_checkpoint_flickr8k_5_cap_per_img_2_min_word_freq_resnet101_finetunefromthestart.pth.tar'>download</a>
