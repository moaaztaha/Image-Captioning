# %%
# !nvidia-smi
# Out:
# Sat Jun 26 10:07:05 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.119.04   Driver Version: 450.119.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# # get the code for kaggle
# !git clone https://github.com/moaaztaha/Image-Captioning
py_files_path = 'Image-Captioning/'
import sys
sys.path.append(py_files_path)
# Out:
# Cloning into 'Image-Captioning'...
# remote: Enumerating objects: 550, done.
# remote: Counting objects: 100% (550/550), done.
# remote: Compressing objects: 100% (250/250), done.
# remote: Total 550 (delta 334), reused 508 (delta 292), pack-reused 0
# Receiving objects: 100% (550/550), 38.27 MiB | 20.04 MiB/s, done.
# Resolving deltas: 100% (334/334), done.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import time 
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence
from models import Encoder, DecoderWithAttention
from dataset import *
from utils import *
from train import *
from torch.utils.tensorboard import SummaryWriter
from os import path as osp

# %%
# Model parameters
encoder_dim = 2048 # resnet101
emb_dim = 512  # dimension of word embeddings
attention_dim = 512  # dimension of attention linear layers
decoder_dim = 512  # dimension of decoder RNN
dropout = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # sets device for model and PyTorch tensors
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# training parameters
epochs = 30  # number of epochs to train for (if early stopping is not triggered)
batch_size = 256
workers = 2
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning
decoder_lr = 4e-4  # learning rate for decoder
fine_tune_encoder = False  # fine-tune encoder?
pretrained_embeddings = False
fine_tune_embeddings = False
checkpoint = None  # path to checkpoint, None if none

# %%
DATA_NAME = 'flickr8k'

# local
# DATA_JSON_PATH = 'data.json'
# IMGS_PATH = 'flickr/Images/'
# kaggle paths
DATA_JSON_PATH = '/kaggle/working/Image-Captioning/data.json'
IMGS_PATH = '../input/flickr8kimagescaptions/flickr8k/images/'
#colab
# DATA_JSON_PATH = 'Image-Captioning/data.json'
# IMGS_PATH = 'flickr8k/images/'

# %%
df = pd.read_json(DATA_JSON_PATH)
df.head()
# Out:
#                    file_name  split  \
# 0  2513260012_03d33305cf.jpg  train
# 1  2513260012_03d33305cf.jpg  train
# 2  2513260012_03d33305cf.jpg  train
# 3  2513260012_03d33305cf.jpg  train
# 4  2513260012_03d33305cf.jpg  train
#
#                                              caption  tok_len  \
# 0  A black dog is running after a white dog in th...       12
# 1           Black dog chasing brown dog through snow        7
# 2  Two dogs chase each other across the snowy gro...        9
# 3               Two dogs play together in the snow .        7
# 4  Two dogs running through a low lying body of w...       10
#
#                                               tokens
# 0  [a, black, dog, is, running, after, a, white, ...
# 1   [black, dog, chasing, brown, dog, through, snow]
# 2  [two, dogs, chase, each, other, across, the, s...
# 3         [two, dogs, play, together, in, the, snow]
# 4  [two, dogs, running, through, a, low, lying, b...

# %%
df.tok_len.max()
# Out:
# 37

# %%
# load vocab
vocab = build_vocab(DATA_JSON_PATH, max_seq=40)
# top10k_words = get_10k_vocab("/content/Image-Captioning/10k_words.txt")
# vocab = top10k_vocab(top10k_words)
vocab_len = len(vocab)
vocab_len
# Out:
# 100%|██████████| 40000/40000 [00:00<00:00, 229257.07it/s]
# 5089

# %%
t_params = {
    'data_name': DATA_NAME,
    'imgs_path': IMGS_PATH,
    'df_path': DATA_JSON_PATH,
    'vocab': vocab,
    'epochs': epochs,
    'batch_size': batch_size,
    'workers': workers,
    'decoder_lr': decoder_lr,
    'encoder_lr': encoder_lr,
    'fine_tune_encoder': fine_tune_encoder,
    'pretrained_embeddings': pretrained_embeddings,
}

m_params = {
    'attention_dim': attention_dim,
    'embed_dim': emb_dim,
    'decoder_dim': decoder_dim,
    'encoder_dim': encoder_dim,
    'dropout': dropout
}

logger_dic = {
    'decoder_lr': decoder_lr,
    'encoder_lr': encoder_lr,
    'fine_tune_encoder': fine_tune_encoder,
    'pretrained_embeddings': pretrained_embeddings,
    'max_seq_length': 100,
    'vocab_size': vocab_len,
    'enocder': 'resnet101',
    'dropout': dropout,
    'attention_dim': attention_dim,
    'embed_dim': emb_dim,
    'decoder_dim': decoder_dim,
    'encoder_dim': encoder_dim 
    
}

# %%
t_params
# Out:
# {'data_name': 'flickr8k',
#  'imgs_path': '../input/flickr8kimagescaptions/flickr8k/images/',
#  'df_path': '/kaggle/working/Image-Captioning/data.json',
#  'vocab': <dataset.Vocabulary at 0x7f753ff65810>,
#  'epochs': 30,
#  'batch_size': 256,
#  'workers': 2,
#  'decoder_lr': 0.0004,
#  'encoder_lr': 0.0001,
#  'fine_tune_encoder': False,
#  'pretrained_embeddings': False}

# %%
# experiment name
name = DATA_NAME + "small_max_seq"
# path
log_dir = '/content/drive/MyDrive/ImageCaptioning/flickr8/experiments_vanilla'

logger = SummaryWriter(log_dir=osp.join(log_dir, name))

# %%
# with scheduler
fit(t_params=t_params, m_params=m_params, logger=logger)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
#   0%|          | 0.00/170M [00:00<?, ?B/s]
# Loading Data
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000
# __________________________________________________
# -------------------- Fitting --------------------
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [0][0/118]	Batch Time 9.531 (9.531)	Data Load Time 5.227 (5.227)	Loss 9.4770 (9.4770)	Top-5 Accuracy 0.134 (0.134)
# Epoch: [0][100/118]	Batch Time 2.872 (2.281)	Data Load Time 1.421 (0.885)	Loss 4.8643 (5.5175)	Top-5 Accuracy 53.353 (44.620)
# Epoch train time 262.880 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 7.065 (7.065)	Loss 5.5638 (5.5638)	Top-5 Accuracy 49.249 (49.249)
# ----- Bleu-n Scores -----
# 1: 56.85350047148461
# 2: 30.66176031276061
# 3: 13.782722962087693
# 4: 5.9202819152917705
# -------------------------
#
#  * LOSS - 5.445, TOP-5 ACCURACY - 51.106, BLEU-4 - 5.9202819152917705
#
# Epoch validation time 57.856 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [1][0/118]	Batch Time 5.300 (5.300)	Data Load Time 3.897 (3.897)	Loss 4.7080 (4.7080)	Top-5 Accuracy 55.505 (55.505)
# Epoch: [1][100/118]	Batch Time 3.115 (2.180)	Data Load Time 1.676 (0.791)	Loss 4.5234 (4.6057)	Top-5 Accuracy 57.588 (56.941)
# Epoch train time 252.724 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.641 (5.641)	Loss 5.3679 (5.3679)	Top-5 Accuracy 52.904 (52.904)
# ----- Bleu-n Scores -----
# 1: 63.3236348169824
# 2: 37.61381292946736
# 3: 20.082926688271826
# 4: 10.90611643526586
# -------------------------
#
#  * LOSS - 5.280, TOP-5 ACCURACY - 54.463, BLEU-4 - 10.90611643526586
#
# Epoch validation time 52.516 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [2][0/118]	Batch Time 5.299 (5.299)	Data Load Time 3.758 (3.758)	Loss 4.5290 (4.5290)	Top-5 Accuracy 58.356 (58.356)
# Epoch: [2][100/118]	Batch Time 2.750 (2.145)	Data Load Time 1.396 (0.758)	Loss 4.1408 (4.3322)	Top-5 Accuracy 62.121 (60.428)
# Epoch train time 249.008 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.261 (5.261)	Loss 5.1774 (5.1774)	Top-5 Accuracy 56.867 (56.867)
# ----- Bleu-n Scores -----
# 1: 62.90281236708517
# 2: 37.597241618011076
# 3: 21.139693366144886
# 4: 12.021862281322658
# -------------------------
#
#  * LOSS - 5.163, TOP-5 ACCURACY - 56.879, BLEU-4 - 12.021862281322658
#
# Epoch validation time 52.470 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [3][0/118]	Batch Time 4.747 (4.747)	Data Load Time 3.344 (3.344)	Loss 4.2078 (4.2078)	Top-5 Accuracy 61.478 (61.478)
# Epoch: [3][100/118]	Batch Time 2.630 (2.124)	Data Load Time 1.213 (0.738)	Loss 4.1431 (4.1457)	Top-5 Accuracy 62.873 (62.869)
# Epoch train time 246.468 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.385 (5.385)	Loss 5.1139 (5.1139)	Top-5 Accuracy 58.189 (58.189)
# ----- Bleu-n Scores -----
# 1: 64.08842142240664
# 2: 40.33147683181897
# 3: 23.73613724642126
# 4: 14.097999701807664
# -------------------------
#
#  * LOSS - 5.152, TOP-5 ACCURACY - 57.827, BLEU-4 - 14.097999701807664
#
# Epoch validation time 52.449 (epoch_time.avg:.3f)
# Epoch     4: reducing learning rate of group 0 to 4.0000e-05.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [4][0/118]	Batch Time 5.097 (5.097)	Data Load Time 3.658 (3.658)	Loss 4.1080 (4.1080)	Top-5 Accuracy 63.425 (63.425)
# Epoch: [4][100/118]	Batch Time 2.333 (2.102)	Data Load Time 0.882 (0.703)	Loss 3.9464 (4.0052)	Top-5 Accuracy 65.148 (64.676)
# Epoch train time 245.798 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.266 (5.266)	Loss 5.2825 (5.2825)	Top-5 Accuracy 59.735 (59.735)
# ----- Bleu-n Scores -----
# 1: 65.91952168342613
# 2: 41.78088117622345
# 3: 24.795751731342882
# 4: 14.749707520271718
# -------------------------
#
#  * LOSS - 5.060, TOP-5 ACCURACY - 59.077, BLEU-4 - 14.749707520271718
#
# Epoch validation time 52.014 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [5][0/118]	Batch Time 5.005 (5.005)	Data Load Time 3.606 (3.606)	Loss 3.9762 (3.9762)	Top-5 Accuracy 64.886 (64.886)
# Epoch: [5][100/118]	Batch Time 2.673 (2.173)	Data Load Time 1.310 (0.782)	Loss 3.9071 (3.9774)	Top-5 Accuracy 66.557 (65.091)
# Epoch train time 252.208 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.535 (5.535)	Loss 5.1462 (5.1462)	Top-5 Accuracy 58.333 (58.333)
# ----- Bleu-n Scores -----
# 1: 65.85293957602732
# 2: 41.84387330972833
# 3: 24.943342451750144
# 4: 14.897951663225673
# -------------------------
#
#  * LOSS - 5.064, TOP-5 ACCURACY - 59.209, BLEU-4 - 14.897951663225673
#
# Epoch validation time 51.510 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [6][0/118]	Batch Time 5.500 (5.500)	Data Load Time 4.000 (4.000)	Loss 4.0110 (4.0110)	Top-5 Accuracy 63.536 (63.536)
# Epoch: [6][100/118]	Batch Time 2.534 (2.135)	Data Load Time 1.189 (0.747)	Loss 3.8273 (3.9541)	Top-5 Accuracy 67.063 (65.377)
# Epoch train time 247.729 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.450 (5.450)	Loss 5.1018 (5.1018)	Top-5 Accuracy 58.783 (58.783)
# ----- Bleu-n Scores -----
# 1: 65.96594891677834
# 2: 41.95252341232767
# 3: 25.056579643503916
# 4: 14.997323011135192
# -------------------------
#
#  * LOSS - 5.084, TOP-5 ACCURACY - 59.320, BLEU-4 - 14.997323011135192
#
# Epoch validation time 54.401 (epoch_time.avg:.3f)
# Epoch     7: reducing learning rate of group 0 to 4.0000e-06.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [7][0/118]	Batch Time 5.064 (5.064)	Data Load Time 3.583 (3.583)	Loss 3.9336 (3.9336)	Top-5 Accuracy 65.204 (65.204)
# Epoch: [7][100/118]	Batch Time 2.952 (2.147)	Data Load Time 1.527 (0.759)	Loss 4.0000 (3.9410)	Top-5 Accuracy 65.108 (65.599)
# Epoch train time 249.964 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.038 (5.038)	Loss 5.0953 (5.0953)	Top-5 Accuracy 59.307 (59.307)
# ----- Bleu-n Scores -----
# 1: 65.96883452839658
# 2: 41.90019267868025
# 3: 24.928236418386625
# 4: 14.854216557038887
# -------------------------
#
#  * LOSS - 5.075, TOP-5 ACCURACY - 59.360, BLEU-4 - 14.854216557038887
#
# Epoch validation time 52.523 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [8][0/118]	Batch Time 4.956 (4.956)	Data Load Time 3.554 (3.554)	Loss 3.9998 (3.9998)	Top-5 Accuracy 63.728 (63.728)
# Epoch: [8][100/118]	Batch Time 2.791 (2.111)	Data Load Time 1.420 (0.734)	Loss 4.0423 (3.9299)	Top-5 Accuracy 65.158 (65.701)
# Epoch train time 245.721 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.322 (5.322)	Loss 5.3737 (5.3737)	Top-5 Accuracy 58.290 (58.290)
# ----- Bleu-n Scores -----
# 1: 65.9587941120929
# 2: 41.88972396587928
# 3: 24.96556601833238
# 4: 14.908159090626969
# -------------------------
#
#  * LOSS - 5.076, TOP-5 ACCURACY - 59.383, BLEU-4 - 14.908159090626969
#
# Epoch validation time 52.375 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (2,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [9][0/118]	Batch Time 4.608 (4.608)	Data Load Time 3.264 (3.264)	Loss 3.9273 (3.9273)	Top-5 Accuracy 65.169 (65.169)
# Epoch: [9][100/118]	Batch Time 2.784 (2.127)	Data Load Time 1.370 (0.735)	Loss 3.9362 (3.9328)	Top-5 Accuracy 64.994 (65.622)
# Epoch train time 247.378 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.971 (5.971)	Loss 5.1355 (5.1355)	Top-5 Accuracy 58.974 (58.974)
# ----- Bleu-n Scores -----
# 1: 65.98348275607833
# 2: 41.96561399148806
# 3: 25.02024057177703
# 4: 14.949104132772192
# -------------------------
#
#  * LOSS - 5.080, TOP-5 ACCURACY - 59.408, BLEU-4 - 14.949104132772192
#
# Epoch validation time 53.333 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (3,)
# Epoch    10: reducing learning rate of group 0 to 4.0000e-07.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [10][0/118]	Batch Time 4.946 (4.946)	Data Load Time 3.555 (3.555)	Loss 3.9918 (3.9918)	Top-5 Accuracy 65.100 (65.100)
# Epoch: [10][100/118]	Batch Time 1.401 (2.105)	Data Load Time 0.001 (0.725)	Loss 4.0744 (3.9317)	Top-5 Accuracy 63.606 (65.665)
# Epoch train time 246.076 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.503 (5.503)	Loss 4.9807 (4.9807)	Top-5 Accuracy 60.416 (60.416)
# ----- Bleu-n Scores -----
# 1: 66.04813230272201
# 2: 42.061778337418296
# 3: 25.066138271937945
# 4: 14.937810403735055
# -------------------------
#
#  * LOSS - 5.079, TOP-5 ACCURACY - 59.400, BLEU-4 - 14.937810403735055
#
# Epoch validation time 52.711 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (4,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [11][0/118]	Batch Time 5.018 (5.018)	Data Load Time 3.672 (3.672)	Loss 3.8419 (3.8419)	Top-5 Accuracy 67.254 (67.254)
# Epoch: [11][100/118]	Batch Time 2.876 (2.111)	Data Load Time 1.466 (0.726)	Loss 3.8522 (3.9331)	Top-5 Accuracy 67.023 (65.746)
# Epoch train time 246.408 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/20]	Batch Time 5.331 (5.331)	Loss 5.1197 (5.1197)	Top-5 Accuracy 60.130 (60.130)
# ----- Bleu-n Scores -----
# 1: 65.99057243518503
# 2: 41.91315012238246
# 3: 24.945212355564006
# 4: 14.879548857390976
# -------------------------
#
#  * LOSS - 5.079, TOP-5 ACCURACY - 59.446, BLEU-4 - 14.879548857390976
#
# Epoch validation time 52.187 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (5,)
# No improvement for 5 consecutive epochs, terminating...

# %%
torch.cuda.empty_cache()

# %%
batch_size = 64
fine_tune_encoder = True
checkpoint = 'BEST_checkpoint_flickr8k.pth.tar'
# epochs = 30

t_params['batch_size'] = batch_size
t_params['data_name'] = t_params['data_name'] + "_finetune" 
t_params['fine_tune_encoder'] = True
t_params['decoder_lr'] = t_params['decoder_lr'] / 10
# t_params['epochs'] = epochs
t_params
# Out:
# {'data_name': 'flickr8k_finetune',
#  'imgs_path': '../input/flickr8kimagescaptions/flickr8k/images/',
#  'df_path': '/kaggle/working/Image-Captioning/data.json',
#  'vocab': <dataset.Vocabulary at 0x7f753ff65810>,
#  'epochs': 30,
#  'batch_size': 64,
#  'workers': 2,
#  'decoder_lr': 4e-05,
#  'encoder_lr': 0.0001,
#  'fine_tune_encoder': True,
#  'pretrained_embeddings': False}

# %%
fit(t_params, checkpoint=checkpoint, m_params=m_params, logger=logger)
# Out:
# Loaded Checkpoint!!
# Starting Epoch: 7
# Loading Data
# Dataset split: train
# Unique images: 6000
# Total size: 30000
# Dataset split: val
# Unique images: 1000
# Total size: 5000
# __________________________________________________
# -------------------- Fitting --------------------
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [7][0/469]	Batch Time 3.304 (3.304)	Data Load Time 0.980 (0.980)	Loss 4.0045 (4.0045)	Top-5 Accuracy 66.304 (66.304)
# Epoch: [7][100/469]	Batch Time 0.734 (0.763)	Data Load Time 0.000 (0.010)	Loss 4.0089 (4.0392)	Top-5 Accuracy 64.371 (64.151)
# Epoch: [7][200/469]	Batch Time 0.724 (0.746)	Data Load Time 0.000 (0.005)	Loss 4.0815 (3.9990)	Top-5 Accuracy 64.932 (64.777)
# Epoch: [7][300/469]	Batch Time 0.712 (0.743)	Data Load Time 0.000 (0.004)	Loss 4.1129 (3.9804)	Top-5 Accuracy 61.968 (65.052)
# Epoch: [7][400/469]	Batch Time 0.709 (0.741)	Data Load Time 0.000 (0.003)	Loss 3.9733 (3.9678)	Top-5 Accuracy 65.410 (65.290)
# Epoch train time 347.958 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.435 (1.435)	Loss 5.0128 (5.0128)	Top-5 Accuracy 58.075 (58.075)
# ----- Bleu-n Scores -----
# 1: 66.41351403899156
# 2: 42.5723926868693
# 3: 25.398787385339826
# 4: 15.270420447866027
# -------------------------
#
#  * LOSS - 5.070, TOP-5 ACCURACY - 59.694, BLEU-4 - 15.270420447866027
#
# Epoch validation time 51.020 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [8][0/469]	Batch Time 1.658 (1.658)	Data Load Time 0.914 (0.914)	Loss 3.6930 (3.6930)	Top-5 Accuracy 68.775 (68.775)
# Epoch: [8][100/469]	Batch Time 0.717 (0.749)	Data Load Time 0.000 (0.010)	Loss 4.0832 (3.8639)	Top-5 Accuracy 64.276 (67.048)
# Epoch: [8][200/469]	Batch Time 0.728 (0.742)	Data Load Time 0.000 (0.005)	Loss 3.8456 (3.8562)	Top-5 Accuracy 66.844 (67.138)
# Epoch: [8][300/469]	Batch Time 0.709 (0.738)	Data Load Time 0.000 (0.004)	Loss 3.8683 (3.8555)	Top-5 Accuracy 66.347 (67.202)
# Epoch: [8][400/469]	Batch Time 0.725 (0.737)	Data Load Time 0.000 (0.003)	Loss 3.9147 (3.8547)	Top-5 Accuracy 65.866 (67.201)
# Epoch train time 345.539 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.410 (1.410)	Loss 5.4224 (5.4224)	Top-5 Accuracy 57.143 (57.143)
# ----- Bleu-n Scores -----
# 1: 66.45420341960188
# 2: 42.75636618915298
# 3: 25.753961606588703
# 4: 15.445198587156932
# -------------------------
#
#  * LOSS - 5.060, TOP-5 ACCURACY - 59.897, BLEU-4 - 15.445198587156932
#
# Epoch validation time 50.477 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [9][0/469]	Batch Time 1.743 (1.743)	Data Load Time 0.994 (0.994)	Loss 3.9183 (3.9183)	Top-5 Accuracy 63.893 (63.893)
# Epoch: [9][100/469]	Batch Time 0.708 (0.743)	Data Load Time 0.000 (0.010)	Loss 3.7550 (3.8022)	Top-5 Accuracy 68.108 (68.073)
# Epoch: [9][200/469]	Batch Time 0.730 (0.739)	Data Load Time 0.000 (0.006)	Loss 3.7086 (3.7962)	Top-5 Accuracy 68.892 (68.215)
# Epoch: [9][300/469]	Batch Time 0.711 (0.736)	Data Load Time 0.000 (0.004)	Loss 3.6594 (3.7900)	Top-5 Accuracy 71.053 (68.309)
# Epoch: [9][400/469]	Batch Time 0.953 (0.736)	Data Load Time 0.004 (0.003)	Loss 3.8144 (3.7877)	Top-5 Accuracy 67.462 (68.263)
# Epoch train time 344.965 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.430 (1.430)	Loss 4.6633 (4.6633)	Top-5 Accuracy 62.853 (62.853)
# ----- Bleu-n Scores -----
# 1: 66.03205497879384
# 2: 42.3856428487502
# 3: 25.444728320219834
# 4: 15.320634486519449
# -------------------------
#
#  * LOSS - 5.084, TOP-5 ACCURACY - 59.914, BLEU-4 - 15.320634486519449
#
# Epoch validation time 50.626 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [10][0/469]	Batch Time 1.792 (1.792)	Data Load Time 1.022 (1.022)	Loss 3.7121 (3.7121)	Top-5 Accuracy 69.463 (69.463)
# Epoch: [10][100/469]	Batch Time 0.736 (0.747)	Data Load Time 0.000 (0.011)	Loss 3.8428 (3.7104)	Top-5 Accuracy 67.810 (69.444)
# Epoch: [10][200/469]	Batch Time 0.712 (0.739)	Data Load Time 0.000 (0.006)	Loss 3.5974 (3.7260)	Top-5 Accuracy 70.972 (69.200)
# Epoch: [10][300/469]	Batch Time 0.709 (0.737)	Data Load Time 0.000 (0.004)	Loss 3.6243 (3.7300)	Top-5 Accuracy 70.839 (69.192)
# Epoch: [10][400/469]	Batch Time 0.726 (0.736)	Data Load Time 0.000 (0.003)	Loss 3.8959 (3.7341)	Top-5 Accuracy 67.335 (69.158)
# Epoch train time 345.168 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.383 (1.383)	Loss 5.1423 (5.1423)	Top-5 Accuracy 61.295 (61.295)
# ----- Bleu-n Scores -----
# 1: 66.25051665337409
# 2: 42.66304368377774
# 3: 25.885886849484514
# 4: 15.795444143972148
# -------------------------
#
#  * LOSS - 5.078, TOP-5 ACCURACY - 60.059, BLEU-4 - 15.795444143972148
#
# Epoch validation time 52.080 (epoch_time.avg:.3f)
# Epoch     4: reducing learning rate of group 0 to 4.0000e-07.
# Epoch     4: reducing learning rate of group 0 to 1.0000e-05.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [11][0/469]	Batch Time 1.737 (1.737)	Data Load Time 0.968 (0.968)	Loss 3.5765 (3.5765)	Top-5 Accuracy 71.124 (71.124)
# Epoch: [11][100/469]	Batch Time 0.717 (0.748)	Data Load Time 0.000 (0.010)	Loss 3.6428 (3.6554)	Top-5 Accuracy 70.935 (70.235)
# Epoch: [11][200/469]	Batch Time 0.743 (0.741)	Data Load Time 0.000 (0.005)	Loss 3.5741 (3.6513)	Top-5 Accuracy 73.427 (70.369)
# Epoch: [11][300/469]	Batch Time 0.750 (0.737)	Data Load Time 0.000 (0.004)	Loss 3.6199 (3.6522)	Top-5 Accuracy 72.956 (70.357)
# Epoch: [11][400/469]	Batch Time 0.786 (0.737)	Data Load Time 0.000 (0.003)	Loss 3.6915 (3.6518)	Top-5 Accuracy 69.709 (70.383)
# Epoch train time 345.081 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.654 (1.654)	Loss 5.3381 (5.3381)	Top-5 Accuracy 57.005 (57.005)
# ----- Bleu-n Scores -----
# 1: 66.80257186372606
# 2: 43.16551507820466
# 3: 26.190572331391454
# 4: 15.738072285777047
# -------------------------
#
#  * LOSS - 5.069, TOP-5 ACCURACY - 60.176, BLEU-4 - 15.738072285777047
#
# Epoch validation time 52.163 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [12][0/469]	Batch Time 1.800 (1.800)	Data Load Time 1.008 (1.008)	Loss 3.6980 (3.6980)	Top-5 Accuracy 70.423 (70.423)
# Epoch: [12][100/469]	Batch Time 0.735 (0.748)	Data Load Time 0.000 (0.011)	Loss 3.6936 (3.6138)	Top-5 Accuracy 68.217 (70.926)
# Epoch: [12][200/469]	Batch Time 0.701 (0.740)	Data Load Time 0.000 (0.006)	Loss 3.5421 (3.6157)	Top-5 Accuracy 70.899 (70.833)
# Epoch: [12][300/469]	Batch Time 0.741 (0.738)	Data Load Time 0.000 (0.004)	Loss 3.6353 (3.6077)	Top-5 Accuracy 72.656 (70.990)
# Epoch: [12][400/469]	Batch Time 0.722 (0.739)	Data Load Time 0.000 (0.003)	Loss 3.4406 (3.6111)	Top-5 Accuracy 72.859 (70.948)
# Epoch train time 346.594 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.439 (1.439)	Loss 5.2126 (5.2126)	Top-5 Accuracy 60.202 (60.202)
# ----- Bleu-n Scores -----
# 1: 66.9158620560876
# 2: 43.22561172468183
# 3: 26.30283558099624
# 4: 15.958687149759504
# -------------------------
#
#  * LOSS - 5.071, TOP-5 ACCURACY - 60.159, BLEU-4 - 15.958687149759504
#
# Epoch validation time 50.981 (epoch_time.avg:.3f)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [13][0/469]	Batch Time 1.772 (1.772)	Data Load Time 1.003 (1.003)	Loss 3.7138 (3.7138)	Top-5 Accuracy 69.949 (69.949)
# Epoch: [13][100/469]	Batch Time 0.786 (0.748)	Data Load Time 0.000 (0.011)	Loss 3.7196 (3.5889)	Top-5 Accuracy 69.571 (71.358)
# Epoch: [13][200/469]	Batch Time 0.734 (0.741)	Data Load Time 0.000 (0.006)	Loss 3.6566 (3.5981)	Top-5 Accuracy 70.246 (71.276)
# Epoch: [13][300/469]	Batch Time 0.720 (0.739)	Data Load Time 0.000 (0.004)	Loss 3.4585 (3.6000)	Top-5 Accuracy 72.740 (71.210)
# Epoch: [13][400/469]	Batch Time 0.744 (0.740)	Data Load Time 0.000 (0.003)	Loss 3.8212 (3.5977)	Top-5 Accuracy 69.451 (71.248)
# Epoch train time 346.933 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.450 (1.450)	Loss 5.0958 (5.0958)	Top-5 Accuracy 55.219 (55.219)
# ----- Bleu-n Scores -----
# 1: 66.81038787961204
# 2: 43.17889576036372
# 3: 26.177872526882545
# 4: 15.835988008762653
# -------------------------
#
#  * LOSS - 5.075, TOP-5 ACCURACY - 60.199, BLEU-4 - 15.835988008762653
#
# Epoch validation time 51.039 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (1,)
# Epoch     7: reducing learning rate of group 0 to 4.0000e-08.
# Epoch     7: reducing learning rate of group 0 to 1.0000e-06.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [14][0/469]	Batch Time 1.691 (1.691)	Data Load Time 0.922 (0.922)	Loss 3.5216 (3.5216)	Top-5 Accuracy 71.973 (71.973)
# Epoch: [14][100/469]	Batch Time 0.734 (0.750)	Data Load Time 0.000 (0.011)	Loss 3.6234 (3.5880)	Top-5 Accuracy 72.381 (71.266)
# Epoch: [14][200/469]	Batch Time 0.800 (0.745)	Data Load Time 0.000 (0.006)	Loss 3.5502 (3.5769)	Top-5 Accuracy 71.950 (71.426)
# Epoch: [14][300/469]	Batch Time 0.716 (0.741)	Data Load Time 0.000 (0.004)	Loss 3.4926 (3.5781)	Top-5 Accuracy 72.176 (71.413)
# Epoch: [14][400/469]	Batch Time 0.726 (0.739)	Data Load Time 0.001 (0.003)	Loss 3.4365 (3.5756)	Top-5 Accuracy 74.293 (71.472)
# Epoch train time 346.189 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.713 (1.713)	Loss 5.2230 (5.2230)	Top-5 Accuracy 56.093 (56.093)
# ----- Bleu-n Scores -----
# 1: 66.909877415364
# 2: 43.153512222804544
# 3: 26.16377426888227
# 4: 15.810542622720373
# -------------------------
#
#  * LOSS - 5.072, TOP-5 ACCURACY - 60.176, BLEU-4 - 15.810542622720373
#
# Epoch validation time 51.345 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (2,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [15][0/469]	Batch Time 1.769 (1.769)	Data Load Time 0.960 (0.960)	Loss 3.4657 (3.4657)	Top-5 Accuracy 73.656 (73.656)
# Epoch: [15][100/469]	Batch Time 0.739 (0.746)	Data Load Time 0.000 (0.010)	Loss 3.7113 (3.5549)	Top-5 Accuracy 67.995 (71.816)
# Epoch: [15][200/469]	Batch Time 0.745 (0.738)	Data Load Time 0.000 (0.005)	Loss 3.5125 (3.5650)	Top-5 Accuracy 74.178 (71.594)
# Epoch: [15][300/469]	Batch Time 0.694 (0.736)	Data Load Time 0.000 (0.004)	Loss 3.6519 (3.5744)	Top-5 Accuracy 70.774 (71.555)
# Epoch: [15][400/469]	Batch Time 0.717 (0.736)	Data Load Time 0.000 (0.003)	Loss 3.5175 (3.5746)	Top-5 Accuracy 72.237 (71.540)
# Epoch train time 344.687 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.472 (1.472)	Loss 5.3643 (5.3643)	Top-5 Accuracy 58.506 (58.506)
# ----- Bleu-n Scores -----
# 1: 66.87044262359744
# 2: 43.17561677694056
# 3: 26.178431621522048
# 4: 15.822368346881799
# -------------------------
#
#  * LOSS - 5.074, TOP-5 ACCURACY - 60.241, BLEU-4 - 15.822368346881799
#
# Epoch validation time 52.056 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (3,)
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [16][0/469]	Batch Time 1.957 (1.957)	Data Load Time 1.143 (1.143)	Loss 3.4386 (3.4386)	Top-5 Accuracy 73.496 (73.496)
# Epoch: [16][100/469]	Batch Time 0.753 (0.753)	Data Load Time 0.000 (0.012)	Loss 3.7223 (3.5593)	Top-5 Accuracy 70.888 (71.619)
# Epoch: [16][200/469]	Batch Time 0.739 (0.747)	Data Load Time 0.000 (0.006)	Loss 3.4901 (3.5688)	Top-5 Accuracy 72.272 (71.569)
# Epoch: [16][300/469]	Batch Time 0.733 (0.742)	Data Load Time 0.000 (0.004)	Loss 3.5386 (3.5699)	Top-5 Accuracy 71.638 (71.549)
# Epoch: [16][400/469]	Batch Time 0.708 (0.739)	Data Load Time 0.000 (0.003)	Loss 3.4036 (3.5713)	Top-5 Accuracy 73.663 (71.559)
# Epoch train time 346.283 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.387 (1.387)	Loss 5.3091 (5.3091)	Top-5 Accuracy 58.583 (58.583)
# ----- Bleu-n Scores -----
# 1: 66.90181798495382
# 2: 43.18216506356422
# 3: 26.1838047403659
# 4: 15.843417779332894
# -------------------------
#
#  * LOSS - 5.078, TOP-5 ACCURACY - 60.245, BLEU-4 - 15.843417779332894
#
# Epoch validation time 49.969 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (4,)
# Epoch    10: reducing learning rate of group 0 to 4.0000e-09.
# Epoch    10: reducing learning rate of group 0 to 1.0000e-07.
# __________________________________________________
# -------------------- Training --------------------
# Epoch: [17][0/469]	Batch Time 1.731 (1.731)	Data Load Time 0.968 (0.968)	Loss 3.2701 (3.2701)	Top-5 Accuracy 75.974 (75.974)
# Epoch: [17][100/469]	Batch Time 0.788 (0.741)	Data Load Time 0.000 (0.010)	Loss 3.4878 (3.5631)	Top-5 Accuracy 73.704 (71.652)
# Epoch: [17][200/469]	Batch Time 0.870 (0.737)	Data Load Time 0.000 (0.005)	Loss 3.8364 (3.5683)	Top-5 Accuracy 68.152 (71.626)
# Epoch: [17][300/469]	Batch Time 0.720 (0.737)	Data Load Time 0.000 (0.004)	Loss 3.3700 (3.5687)	Top-5 Accuracy 75.000 (71.623)
# Epoch: [17][400/469]	Batch Time 0.713 (0.735)	Data Load Time 0.000 (0.003)	Loss 3.4078 (3.5708)	Top-5 Accuracy 73.871 (71.563)
# Epoch train time 344.510 (epoch_time.avg:.3f)
# -------------------- Validation --------------------
# Validation: [0/79]	Batch Time 1.402 (1.402)	Loss 5.3803 (5.3803)	Top-5 Accuracy 59.450 (59.450)
# ----- Bleu-n Scores -----
# 1: 66.91022982904184
# 2: 43.25093204571957
# 3: 26.25218101355674
# 4: 15.868762924866733
# -------------------------
#
#  * LOSS - 5.076, TOP-5 ACCURACY - 60.220, BLEU-4 - 15.868762924866733
#
# Epoch validation time 49.677 (epoch_time.avg:.3f)
#
# Epochs since last improvement: (5,)
# No improvement for 5 consecutive epochs, terminating...

# %%
checkpoint = load_checkpoint("BEST_checkpoint_flickr8k_finetune.pth.tar")
decoder = checkpoint['decoder']
decoder = decoder.to(device)
decoder.eval()
encoder = checkpoint['encoder']
encoder = encoder.to(device)
encoder.eval();
# Out:
# Loaded Checkpoint!!
# Last Epoch: 12
# Best Bleu-4: 15.958687149759504

# %%
from eval import test_score

test_dict = {}

for i in [1, 3, 5]:
    
    b1, b2, b3, b4 = test_score(i, encoder, decoder, IMGS_PATH, DATA_JSON_PATH, vocab)
    if i == 3:
        test_dict['b1'] = b1
        test_dict['b2'] = b2
        test_dict['b3'] = b3
    
    test_dict[f'b4-b{i}'] = b4
# Out:
# EVALUATING AT BEAM SIZE 1:   0%|          | 0/5000 [00:00<?, ?it/s]
# Dataset split: test
# Unique images: 1000
# Total size: 5000
# EVALUATING AT BEAM SIZE 1: 100%|██████████| 5000/5000 [03:51<00:00, 21.56it/s]
# ----- Bleu-n Scores -----
# 1: 60.587742955454296
# 2: 43.942940128884835
# 3: 30.54183515877139
# 4: 21.042882148918814
# -------------------------
# EVALUATING AT BEAM SIZE 3:   0%|          | 0/5000 [00:00<?, ?it/s]
# Dataset split: test
# Unique images: 1000
# Total size: 5000
# EVALUATING AT BEAM SIZE 3: 100%|██████████| 5000/5000 [04:29<00:00, 18.55it/s]
# ----- Bleu-n Scores -----
# 1: 63.9591916813812
# 2: 46.76456351470242
# 3: 33.10728567829948
# 4: 23.041341382869543
# -------------------------
# EVALUATING AT BEAM SIZE 5:   0%|          | 0/5000 [00:00<?, ?it/s]
# Dataset split: test
# Unique images: 1000
# Total size: 5000
# EVALUATING AT BEAM SIZE 5: 100%|██████████| 5000/5000 [04:45<00:00, 17.53it/s]
# ----- Bleu-n Scores -----
# 1: 65.0749640583282
# 2: 47.37754712439627
# 3: 33.51688921329188
# 4: 23.1951649964219
# -------------------------

# %%
# final results -> different from training and validation scalars
results_dic =  {
    # train & valid
    'total_epochs': 16,
    'b-1/test': test_dict['b1'],
    'b-2/test': test_dict['b2'],
    'b-3/test': test_dict['b3'],
    'b-4/b3': test_dict['b4-b3'],
    'b-4/b1': test_dict['b4-b1'],
    'b-4/b5': test_dict['b4-b5']
}

# %%
logger.add_hparams(logger_dic, results_dic, run_name='flickr_small_max_seq')

# %%
# !ls
# Out:
# BEST_checkpoint_flickr8k.pth.tar	   __notebook_source__.ipynb
# BEST_checkpoint_flickr8k_finetune.pth.tar  checkpoint_flickr8k.pth.tar
# Image-Captioning			   checkpoint_flickr8k_finetune.pth.tar
